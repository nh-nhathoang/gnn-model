# %%
import argparse
import numpy as np
import torch.nn as nn
import torch.optim as optim
import matplotlib.pyplot as plt

from utils.GNN_data import *
from utils.GNN_model import GIN
from utils.train_model import train_model
from utils.evaluate_model import *

# %%
parser = argparse.ArgumentParser()
parser.add_argument('--batch_num', type=int, default=64, help='batch size') 
parser.add_argument('--epoch_num', type=int, default=250, help='Epoch number') 
parser.add_argument('--cover_interval', type=int, default=20, help='Cover interval')
parser.add_argument('--overlap', type=float, default=0.3, help='cover overlap')
parser.add_argument('--save_model_dir', type=str, default='./examples/saved_GNN_model', help='saved GNN model directory')
args = parser.parse_args([])
#2 features
#epoch_num = 250 -> converge
#batch = 64
#dim_h = 64
#running time about 15 minutes

# %%
from torch_geometric.data import Data
import torch 
def load_inp_data(file_path, label):
    nodes, edges = [], []
    
    with open(file_path, 'r') as file:
        lines = file.readlines()

        node_section = False
        element_section = False

        for line in lines:
            line = line.strip()

            if "*Node" in line:
                node_section = True
                element_section = False
                continue

            if "*Element" in line:
                node_section = False
                element_section = True
                continue

            # Skip invalid lines like "*Nset" or "*Elset"
            if "*Nset" in line or "*Elset" in line:
                node_section = False
                element_section = False
                continue

            if node_section:
                parts = line.split(',')
                if len(parts) >= 3:
                    try:
                        x, y = float(parts[1].strip()), float(parts[2].strip())
                        nodes.append([x, y])
                    except ValueError:
                        continue

            if element_section:
                parts = line.split(',')
                if len(parts) >= 3 and parts[0].strip().isdigit() and parts[1].strip().isdigit() and parts[2].strip().isdigit():
                    start, end = int(parts[1].strip()) - 1, int(parts[2].strip()) - 1  # Convert 1-indexed to 0-indexed
                    
                    if start == end:
                        continue
                    
                    # Ensure indices are within valid range
                    if start < len(nodes) and end < len(nodes):
                        edges.append([start, end])
                    else:
                        print(f"Skipping invalid edge ({start+1}, {end+1}) in {file_path}")

    node_tensor = torch.tensor(nodes, dtype=torch.float)
    edge_tensor = torch.tensor(edges, dtype=torch.long).t().contiguous() if edges else torch.empty((2, 0), dtype=torch.long)

    data = Data(x=node_tensor, edge_index=edge_tensor, K=np.float64(label * 200000.00))
    return data

# %% [markdown]
# # Data loading

# %%
import os
from glob import glob

folder_list = ['Kagome', 'Hexagonal', 'Demi-A', 'Demi-B', 'Demi-C']
base_path = '.'  # or wherever your dataset folders are

dataset = []

for folder in folder_list:
    results_path = os.path.join(base_path, folder, 'Results.txt')
    inp_folder = os.path.join(base_path, folder, 'inp_files')

    # Parse Results.txt in the current folder
    file_labels = {}
    with open(results_path, 'r') as file:
        for line in file:
            if line.strip() == "" or "E/Es" in line:
                continue
            try:
                file_name, label = line.strip().split(', ')
                filename = file_name.strip().split('.')[0]
                label = float(label)
                file_labels[filename] = label
            except ValueError:
                print(f"[{folder}] Skipping invalid line: {line.strip()}")

    # Load each corresponding .inp file
    for file, label in file_labels.items():
        file_path = os.path.join(inp_folder, f"{file}.inp")
        if os.path.exists(file_path):
            data = load_inp_data(file_path, label)
            if data is not None:
                dataset.append(data)
        else:
            print(f"[{folder}] Missing file: {file_path}")

# %%
dataset
# Out:
# [Data(x=[104, 2], edge_index=[2, 180], K=3334.25610352),
#  Data(x=[104, 2], edge_index=[2, 180], K=3319.36621094),
#  Data(x=[104, 2], edge_index=[2, 180], K=3317.578125),
#  Data(x=[104, 2], edge_index=[2, 180], K=3311.75683594),
#  Data(x=[104, 2], edge_index=[2, 180], K=3309.0815429599998),
#  Data(x=[104, 2], edge_index=[2, 180], K=3302.2961425800004),
#  Data(x=[104, 2], edge_index=[2, 180], K=3319.8339843800004),
#  Data(x=[104, 2], edge_index=[2, 180], K=3320.16333008),
#  Data(x=[104, 2], edge_index=[2, 180], K=3303.1911621),
#  Data(x=[104, 2], edge_index=[2, 180], K=3309.5705566399997),
#  Data(x=[104, 2], edge_index=[2, 180], K=3318.5014648399997),
#  Data(x=[104, 2], edge_index=[2, 180], K=3328.02441406),
#  Data(x=[104, 2], edge_index=[2, 180], K=3314.78710938),
#  Data(x=[104, 2], edge_index=[2, 180], K=3312.81298828),
#  Data(x=[104, 2], edge_index=[2, 180], K=3311.1208496),
#  Data(x=[104, 2], edge_index=[2, 180], K=3318.1435546800003),
#  Data(x=[104, 2], edge_index=[2, 180], K=3292.6213379),
#  Data(x=[104, 2], edge_index=[2, 180], K=3298.9199218800004),
#  Data(x=[104, 2], edge_index=[2, 180], K=3301.59375),
#  Data(x=[104, 2], edge_index=[2, 180], K=3306.6208496),
#  Data(x=[104, 2], edge_index=[2, 180], K=3316.7929687599994),
#  Data(x=[104, 2], edge_index=[2, 180], K=3268.86621094),
#  Data(x=[104, 2], edge_index=[2, 180], K=3269.87475586),
#  Data(x=[104, 2], edge_index=[2, 180], K=3249.2421874999995),
#  Data(x=[104, 2], edge_index=[2, 180], K=3260.8713379),
#  Data(x=[104, 2], edge_index=[2, 180], K=3257.2512207),
#  Data(x=[104, 2], edge_index=[2, 180], K=3266.2216796800003),
#  Data(x=[104, 2], edge_index=[2, 180], K=3261.67211914),
#  Data(x=[104, 2], edge_index=[2, 180], K=3219.1811523399997),
#  Data(x=[104, 2], edge_index=[2, 180], K=3277.53833008),
#  Data(x=[104, 2], edge_index=[2, 180], K=3273.8720703199997),
#  Data(x=[104, 2], edge_index=[2, 180], K=3272.5058593799995),
#  Data(x=[104, 2], edge_index=[2, 180], K=3267.20751954),
#  Data(x=[104, 2], edge_index=[2, 180], K=3211.4865722600002),
#  Data(x=[104, 2], edge_index=[2, 180], K=3273.05932618),
#  Data(x=[104, 2], edge_index=[2, 180], K=3253.16918946),
#  Data(x=[104, 2], edge_index=[2, 180], K=3248.76879882),
#  Data(x=[104, 2], edge_index=[2, 180], K=3253.95092774),
#  Data(x=[104, 2], edge_index=[2, 180], K=3252.13354492),
#  Data(x=[104, 2], edge_index=[2, 180], K=3260.2658691399997),
#  Data(x=[104, 2], edge_index=[2, 180], K=3243.5993652399998),
#  Data(x=[104, 2], edge_index=[2, 180], K=3058.2770996),
#  Data(x=[104, 2], edge_index=[2, 180], K=3160.4904785199997),
#  Data(x=[104, 2], edge_index=[2, 180], K=3202.5969238200005),
#  Data(x=[104, 2], edge_index=[2, 180], K=3227.8569336),
#  Data(x=[104, 2], edge_index=[2, 180], K=3225.0253906199996),
#  Data(x=[104, 2], edge_index=[2, 180], K=2903.14013672),
#  Data(x=[104, 2], edge_index=[2, 180], K=3262.61206054),
#  Data(x=[104, 2], edge_index=[2, 180], K=3094.0432129),
#  Data(x=[104, 2], edge_index=[2, 180], K=2867.9519043),
#  Data(x=[104, 2], edge_index=[2, 180], K=3130.24169922),
#  Data(x=[104, 2], edge_index=[2, 180], K=3011.5549316399997),
#  Data(x=[104, 2], edge_index=[2, 180], K=3130.8520507800004),
#  Data(x=[104, 2], edge_index=[2, 180], K=3131.40283204),
#  Data(x=[104, 2], edge_index=[2, 180], K=3199.12036132),
#  Data(x=[104, 2], edge_index=[2, 180], K=3261.68286132),
#  Data(x=[104, 2], edge_index=[2, 180], K=3202.4152831999995),
#  Data(x=[104, 2], edge_index=[2, 180], K=3246.55664062),
#  Data(x=[104, 2], edge_index=[2, 180], K=3170.32128906),
#  Data(x=[104, 2], edge_index=[2, 180], K=3106.73266602),
#  Data(x=[104, 2], edge_index=[2, 180], K=3225.7084961),
#  Data(x=[104, 2], edge_index=[2, 180], K=3022.9631347600002),
#  Data(x=[104, 2], edge_index=[2, 180], K=2801.65600586),
#  Data(x=[104, 2], edge_index=[2, 180], K=3154.17407226),
#  Data(x=[104, 2], edge_index=[2, 180], K=2996.19750976),
#  Data(x=[104, 2], edge_index=[2, 180], K=2981.3540039),
#  Data(x=[104, 2], edge_index=[2, 180], K=3109.140625),
#  Data(x=[104, 2], edge_index=[2, 180], K=3179.4621582),
#  Data(x=[104, 2], edge_index=[2, 180], K=3159.10375976),
#  Data(x=[104, 2], edge_index=[2, 180], K=2973.37231446),
#  Data(x=[104, 2], edge_index=[2, 180], K=2842.5883789),
#  Data(x=[104, 2], edge_index=[2, 180], K=3204.79248046),
#  Data(x=[104, 2], edge_index=[2, 180], K=3063.33764648),
#  Data(x=[104, 2], edge_index=[2, 180], K=2996.34838868),
#  Data(x=[104, 2], edge_index=[2, 180], K=3197.24829102),
#  Data(x=[104, 2], edge_index=[2, 180], K=3101.00634766),
#  Data(x=[104, 2], edge_index=[2, 180], K=2865.06518554),
#  Data(x=[104, 2], edge_index=[2, 180], K=3000.74902344),
#  Data(x=[104, 2], edge_index=[2, 180], K=2900.06298828),
#  Data(x=[104, 2], edge_index=[2, 180], K=2934.12304688),
#  Data(x=[104, 2], edge_index=[2, 180], K=3168.8552246),
#  Data(x=[104, 2], edge_index=[2, 180], K=3124.9963379),
#  Data(x=[104, 2], edge_index=[2, 180], K=2409.5727539),
#  Data(x=[104, 2], edge_index=[2, 180], K=3094.3986816399997),
#  Data(x=[104, 2], edge_index=[2, 180], K=2943.4465332),
#  Data(x=[104, 2], edge_index=[2, 180], K=2854.57104492),
#  Data(x=[104, 2], edge_index=[2, 180], K=3119.3168945400002),
#  Data(x=[104, 2], edge_index=[2, 180], K=2735.8383789),
#  Data(x=[104, 2], edge_index=[2, 180], K=3020.0197754),
#  Data(x=[104, 2], edge_index=[2, 180], K=2884.53515624),
#  Data(x=[104, 2], edge_index=[2, 180], K=2942.49658204),
#  Data(x=[104, 2], edge_index=[2, 180], K=2611.70898438),
#  Data(x=[104, 2], edge_index=[2, 180], K=3166.55151368),
#  Data(x=[104, 2], edge_index=[2, 180], K=2787.77270508),
#  Data(x=[104, 2], edge_index=[2, 180], K=3070.2680664),
#  Data(x=[104, 2], edge_index=[2, 180], K=3014.71118164),
#  Data(x=[104, 2], edge_index=[2, 180], K=2778.5200195400002),
#  Data(x=[104, 2], edge_index=[2, 180], K=2922.6328125),
#  Data(x=[104, 2], edge_index=[2, 180], K=2945.2763671800003),
#  Data(x=[104, 2], edge_index=[2, 180], K=2879.1574707),
#  Data(x=[104, 2], edge_index=[2, 180], K=2829.3828125),
#  Data(x=[104, 2], edge_index=[2, 180], K=2767.5212402399998),
#  Data(x=[104, 2], edge_index=[2, 180], K=2912.6469726600003),
#  Data(x=[104, 2], edge_index=[2, 180], K=2682.96362304),
#  Data(x=[104, 2], edge_index=[2, 180], K=2901.17797852),
#  Data(x=[104, 2], edge_index=[2, 180], K=2896.55517578),
#  Data(x=[104, 2], edge_index=[2, 180], K=2865.40698242),
#  Data(x=[104, 2], edge_index=[2, 180], K=2983.0769043),
#  Data(x=[104, 2], edge_index=[2, 180], K=2646.72705078),
#  Data(x=[104, 2], edge_index=[2, 180], K=2965.0300293),
#  Data(x=[104, 2], edge_index=[2, 180], K=2584.0534668),
#  Data(x=[104, 2], edge_index=[2, 180], K=2948.4104004),
#  Data(x=[104, 2], edge_index=[2, 180], K=2391.3227539),
#  Data(x=[104, 2], edge_index=[2, 180], K=3015.61767578),
#  Data(x=[104, 2], edge_index=[2, 180], K=2539.2124023399997),
#  Data(x=[104, 2], edge_index=[2, 180], K=2739.1520996),
#  Data(x=[104, 2], edge_index=[2, 180], K=2912.84521484),
#  Data(x=[104, 2], edge_index=[2, 180], K=2854.1364746),
#  Data(x=[104, 2], edge_index=[2, 180], K=2937.16088868),
#  Data(x=[104, 2], edge_index=[2, 180], K=2758.62548828),
#  Data(x=[104, 2], edge_index=[2, 180], K=2884.03344726),
#  Data(x=[104, 2], edge_index=[2, 180], K=2901.86938476),
#  Data(x=[104, 2], edge_index=[2, 180], K=2949.6652832),
#  Data(x=[104, 2], edge_index=[2, 180], K=2974.34375),
#  Data(x=[104, 2], edge_index=[2, 180], K=2992.75219726),
#  Data(x=[104, 2], edge_index=[2, 180], K=2383.0349121),
#  Data(x=[104, 2], edge_index=[2, 180], K=2824.0290527399998),
#  Data(x=[104, 2], edge_index=[2, 180], K=2855.8818359399997),
#  Data(x=[104, 2], edge_index=[2, 180], K=2624.3459472600002),
#  Data(x=[104, 2], edge_index=[2, 180], K=2538.21191406),
#  Data(x=[104, 2], edge_index=[2, 180], K=2732.20898438),
#  Data(x=[104, 2], edge_index=[2, 180], K=2651.56420898),
#  Data(x=[104, 2], edge_index=[2, 180], K=2788.42504882),
#  Data(x=[104, 2], edge_index=[2, 180], K=2252.56958008),
#  Data(x=[104, 2], edge_index=[2, 180], K=2895.71484376),
#  Data(x=[104, 2], edge_index=[2, 180], K=2775.0065918),
#  Data(x=[104, 2], edge_index=[2, 180], K=2487.8654785199997),
#  Data(x=[104, 2], edge_index=[2, 180], K=2736.36694336),
#  Data(x=[104, 2], edge_index=[2, 180], K=2928.29614258),
#  Data(x=[104, 2], edge_index=[2, 180], K=2695.56030274),
#  Data(x=[104, 2], edge_index=[2, 180], K=2552.48388672),
#  Data(x=[104, 2], edge_index=[2, 180], K=2083.99731446),
#  Data(x=[104, 2], edge_index=[2, 180], K=2194.8459472600002),
#  Data(x=[104, 2], edge_index=[2, 180], K=2263.96289062),
#  Data(x=[104, 2], edge_index=[2, 180], K=2565.38061524),
#  Data(x=[104, 2], edge_index=[2, 180], K=2596.9128418),
#  Data(x=[104, 2], edge_index=[2, 180], K=2437.0974121),
#  Data(x=[104, 2], edge_index=[2, 180], K=2779.65551758),
#  Data(x=[104, 2], edge_index=[2, 180], K=2620.6252441399997),
#  Data(x=[104, 2], edge_index=[2, 180], K=2276.12158204),
#  Data(x=[104, 2], edge_index=[2, 180], K=2540.94262696),
#  Data(x=[104, 2], edge_index=[2, 180], K=2739.3046875),
#  Data(x=[104, 2], edge_index=[2, 180], K=2322.51855468),
#  Data(x=[104, 2], edge_index=[2, 180], K=2700.5456543),
#  Data(x=[104, 2], edge_index=[2, 180], K=2568.1130371),
#  Data(x=[104, 2], edge_index=[2, 180], K=2812.97143554),
#  Data(x=[104, 2], edge_index=[2, 180], K=2398.85131836),
#  Data(x=[104, 2], edge_index=[2, 180], K=2851.3947754),
#  Data(x=[104, 2], edge_index=[2, 180], K=2792.68603516),
#  Data(x=[104, 2], edge_index=[2, 180], K=2240.45776368),
#  Data(x=[104, 2], edge_index=[2, 180], K=2536.58984374),
#  Data(x=[104, 2], edge_index=[2, 180], K=2703.6743164),
#  Data(x=[104, 2], edge_index=[2, 180], K=2460.4645996),
#  Data(x=[104, 2], edge_index=[2, 180], K=1811.7669677739998),
#  Data(x=[104, 2], edge_index=[2, 180], K=2274.46704102),
#  Data(x=[104, 2], edge_index=[2, 180], K=2323.59301758),
#  Data(x=[104, 2], edge_index=[2, 180], K=2173.04296876),
#  Data(x=[104, 2], edge_index=[2, 180], K=2215.93359374),
#  Data(x=[104, 2], edge_index=[2, 180], K=2373.36328124),
#  Data(x=[104, 2], edge_index=[2, 180], K=2531.81176758),
#  Data(x=[104, 2], edge_index=[2, 180], K=2725.42382812),
#  Data(x=[104, 2], edge_index=[2, 180], K=2427.9975586),
#  Data(x=[104, 2], edge_index=[2, 180], K=2153.64941406),
#  Data(x=[104, 2], edge_index=[2, 180], K=2544.09106446),
#  Data(x=[104, 2], edge_index=[2, 180], K=2714.3940429599998),
#  Data(x=[104, 2], edge_index=[2, 180], K=2426.23486328),
#  Data(x=[104, 2], edge_index=[2, 180], K=2374.43530274),
#  Data(x=[104, 2], edge_index=[2, 180], K=2444.62207032),
#  Data(x=[104, 2], edge_index=[2, 180], K=2532.1303711),
#  Data(x=[104, 2], edge_index=[2, 180], K=2145.0659179599998),
#  Data(x=[104, 2], edge_index=[2, 180], K=2652.3696289),
#  Data(x=[104, 2], edge_index=[2, 180], K=2484.48046874),
#  Data(x=[104, 2], edge_index=[2, 180], K=2463.59033204),
#  Data(x=[104, 2], edge_index=[2, 180], K=2494.67895508),
#  Data(x=[104, 2], edge_index=[2, 180], K=2640.08569336),
#  Data(x=[104, 2], edge_index=[2, 180], K=2109.4350586),
#  Data(x=[104, 2], edge_index=[2, 180], K=2439.1340332),
#  Data(x=[104, 2], edge_index=[2, 180], K=2585.82763672),
#  Data(x=[104, 2], edge_index=[2, 180], K=2464.09399414),
#  Data(x=[104, 2], edge_index=[2, 180], K=2088.21972656),
#  Data(x=[104, 2], edge_index=[2, 180], K=2744.38500976),
#  Data(x=[104, 2], edge_index=[2, 180], K=1899.7344970699999),
#  Data(x=[104, 2], edge_index=[2, 180], K=2388.3115234399997),
#  Data(x=[104, 2], edge_index=[2, 180], K=1984.3941650400002),
#  Data(x=[104, 2], edge_index=[2, 180], K=2590.6037597600002),
#  Data(x=[104, 2], edge_index=[2, 180], K=2190.49414062),
#  Data(x=[104, 2], edge_index=[2, 180], K=2582.17333984),
#  Data(x=[104, 2], edge_index=[2, 180], K=2591.96972656),
#  Data(x=[104, 2], edge_index=[2, 180], K=2682.5900879),
#  Data(x=[104, 2], edge_index=[2, 180], K=2454.32128906),
#  Data(x=[104, 2], edge_index=[2, 180], K=2235.15942382),
#  Data(x=[104, 2], edge_index=[2, 180], K=2106.4699707),
#  Data(x=[104, 2], edge_index=[2, 180], K=1485.603271484),
#  Data(x=[104, 2], edge_index=[2, 180], K=2110.8442382800004),
#  Data(x=[104, 2], edge_index=[2, 180], K=2544.55810546),
#  Data(x=[104, 2], edge_index=[2, 180], K=2300.59082032),
#  Data(x=[104, 2], edge_index=[2, 180], K=1573.193603516),
#  Data(x=[104, 2], edge_index=[2, 180], K=2248.41552734),
#  Data(x=[104, 2], edge_index=[2, 180], K=1640.190307618),
#  Data(x=[104, 2], edge_index=[2, 180], K=2299.19384766),
#  Data(x=[104, 2], edge_index=[2, 180], K=2166.1525879),
#  Data(x=[104, 2], edge_index=[2, 180], K=2171.76635742),
#  Data(x=[104, 2], edge_index=[2, 180], K=1889.5343017579999),
#  Data(x=[104, 2], edge_index=[2, 180], K=2191.40356446),
#  Data(x=[104, 2], edge_index=[2, 180], K=2351.16723632),
#  Data(x=[104, 2], edge_index=[2, 180], K=1795.497802734),
#  Data(x=[104, 2], edge_index=[2, 180], K=1965.127075196),
#  Data(x=[104, 2], edge_index=[2, 180], K=1993.614257812),
#  Data(x=[104, 2], edge_index=[2, 180], K=2103.88549804),
#  Data(x=[104, 2], edge_index=[2, 180], K=1828.987670898),
#  Data(x=[104, 2], edge_index=[2, 180], K=2049.31030274),
#  Data(x=[104, 2], edge_index=[2, 180], K=2085.98632812),
#  Data(x=[104, 2], edge_index=[2, 180], K=2147.6652832),
#  Data(x=[104, 2], edge_index=[2, 180], K=2328.5771484399997),
#  Data(x=[104, 2], edge_index=[2, 180], K=2654.13769532),
#  Data(x=[104, 2], edge_index=[2, 180], K=2174.50854492),
#  Data(x=[104, 2], edge_index=[2, 180], K=2184.56176758),
#  Data(x=[104, 2], edge_index=[2, 180], K=1772.909057618),
#  Data(x=[104, 2], edge_index=[2, 180], K=2234.4414062600003),
#  Data(x=[104, 2], edge_index=[2, 180], K=1537.2524414060001),
#  Data(x=[104, 2], edge_index=[2, 180], K=2558.97167968),
#  Data(x=[104, 2], edge_index=[2, 180], K=2327.87646484),
#  Data(x=[104, 2], edge_index=[2, 180], K=2254.9294433600003),
#  Data(x=[104, 2], edge_index=[2, 180], K=2314.15039062),
#  Data(x=[104, 2], edge_index=[2, 180], K=2041.8204345799998),
#  Data(x=[104, 2], edge_index=[2, 180], K=2147.07128906),
#  Data(x=[104, 2], edge_index=[2, 180], K=2380.35449218),
#  Data(x=[104, 2], edge_index=[2, 180], K=1551.755737304),
#  Data(x=[104, 2], edge_index=[2, 180], K=2440.7326660199997),
#  Data(x=[104, 2], edge_index=[2, 180], K=1808.0141601560001),
#  Data(x=[104, 2], edge_index=[2, 180], K=2017.4792480400001),
#  Data(x=[104, 2], edge_index=[2, 180], K=1070.379516602),
#  Data(x=[104, 2], edge_index=[2, 180], K=1621.8916015620002),
#  Data(x=[104, 2], edge_index=[2, 180], K=1856.3125),
#  Data(x=[104, 2], edge_index=[2, 180], K=1329.940307618),
#  Data(x=[104, 2], edge_index=[2, 180], K=1723.9635009760002),
#  Data(x=[104, 2], edge_index=[2, 180], K=1332.4514160160002),
#  Data(x=[104, 2], edge_index=[2, 180], K=2368.15844726),
#  Data(x=[104, 2], edge_index=[2, 180], K=2390.7067871),
#  Data(x=[104, 2], edge_index=[2, 180], K=1424.217041016),
#  Data(x=[104, 2], edge_index=[2, 180], K=1829.518798828),
#  Data(x=[104, 2], edge_index=[2, 180], K=1738.7098388680001),
#  Data(x=[104, 2], edge_index=[2, 180], K=2849.0119629),
#  Data(x=[104, 2], edge_index=[2, 180], K=1482.1815185540001),
#  Data(x=[104, 2], edge_index=[2, 180], K=1509.020263672),
#  Data(x=[104, 2], edge_index=[2, 180], K=1753.243041992),
#  Data(x=[104, 2], edge_index=[2, 180], K=1795.590576172),
#  Data(x=[104, 2], edge_index=[2, 180], K=1997.049072266),
#  Data(x=[104, 2], edge_index=[2, 180], K=1881.356079102),
#  Data(x=[104, 2], edge_index=[2, 180], K=1963.74255371),
#  Data(x=[104, 2], edge_index=[2, 180], K=1781.874145508),
#  Data(x=[104, 2], edge_index=[2, 180], K=1187.729736328),
#  Data(x=[104, 2], edge_index=[2, 180], K=2022.58935546),
#  Data(x=[104, 2], edge_index=[2, 180], K=2191.2006836),
#  Data(x=[104, 2], edge_index=[2, 180], K=1775.51159668),
#  Data(x=[104, 2], edge_index=[2, 180], K=2065.81762696),
#  Data(x=[104, 2], edge_index=[2, 180], K=2061.9467773399997),
#  Data(x=[104, 2], edge_index=[2, 180], K=1536.218017578),
#  Data(x=[104, 2], edge_index=[2, 180], K=2024.8730468799997),
#  Data(x=[104, 2], edge_index=[2, 180], K=1504.4317626959999),
#  Data(x=[104, 2], edge_index=[2, 180], K=1775.710327148),
#  Data(x=[104, 2], edge_index=[2, 180], K=1865.146850586),
#  Data(x=[104, 2], edge_index=[2, 180], K=1758.19104004),
#  Data(x=[104, 2], edge_index=[2, 180], K=1876.59411621),
#  Data(x=[104, 2], edge_index=[2, 180], K=2072.1274414),
#  Data(x=[104, 2], edge_index=[2, 180], K=1400.38659668),
#  Data(x=[104, 2], edge_index=[2, 180], K=1662.8258056640002),
#  Data(x=[104, 2], edge_index=[2, 180], K=2160.22680664),
#  Data(x=[104, 2], edge_index=[2, 180], K=2328.40356446),
#  Data(x=[104, 2], edge_index=[2, 180], K=1138.978515626),
#  Data(x=[104, 2], edge_index=[2, 180], K=2175.93286132),
#  Data(x=[104, 2], edge_index=[2, 180], K=1912.3245849599998),
#  Data(x=[104, 2], edge_index=[2, 180], K=1801.0351562499998),
#  Data(x=[104, 2], edge_index=[2, 180], K=2084.4243164),
#  Data(x=[104, 2], edge_index=[2, 180], K=1983.223388672),
#  Data(x=[104, 2], edge_index=[2, 180], K=2016.17150878),
#  Data(x=[104, 2], edge_index=[2, 180], K=1936.596923828),
#  Data(x=[104, 2], edge_index=[2, 180], K=1603.6320800780002),
#  Data(x=[104, 2], edge_index=[2, 180], K=2303.7856445400002),
#  Data(x=[104, 2], edge_index=[2, 180], K=1946.548950196),
#  Data(x=[104, 2], edge_index=[2, 180], K=2352.58007812),
#  Data(x=[104, 2], edge_index=[2, 180], K=1852.6462402339998),
#  Data(x=[104, 2], edge_index=[2, 180], K=1315.774291992),
#  Data(x=[104, 2], edge_index=[2, 180], K=2127.8549804599998),
#  Data(x=[104, 2], edge_index=[2, 180], K=1702.1885986319999),
#  Data(x=[104, 2], edge_index=[2, 180], K=2321.28808594),
#  Data(x=[104, 2], edge_index=[2, 180], K=1286.46118164),
#  Data(x=[104, 2], edge_index=[2, 180], K=1105.700195312),
#  Data(x=[104, 2], edge_index=[2, 180], K=1565.080078126),
#  Data(x=[104, 2], edge_index=[2, 180], K=2409.31347656),
#  Data(x=[104, 2], edge_index=[2, 180], K=1241.092285156),
#  Data(x=[104, 2], edge_index=[2, 180], K=1760.2130126959999),
#  Data(x=[104, 2], edge_index=[2, 180], K=1359.24963379),
#  Data(x=[104, 2], edge_index=[2, 180], K=1678.252929688),
#  Data(x=[104, 2], edge_index=[2, 180], K=1561.935791016),
#  Data(x=[104, 2], edge_index=[2, 180], K=1752.0668945319999),
#  Data(x=[104, 2], edge_index=[2, 180], K=2252.8840332),
#  Data(x=[104, 2], edge_index=[2, 180], K=1292.790771484),
#  Data(x=[104, 2], edge_index=[2, 180], K=1288.541992188),
#  Data(x=[104, 2], edge_index=[2, 180], K=1063.80432129),
#  Data(x=[104, 2], edge_index=[2, 180], K=1452.54284668),
#  Data(x=[104, 2], edge_index=[2, 180], K=1691.87866211),
#  Data(x=[104, 2], edge_index=[2, 180], K=1880.8723144540002),
#  Data(x=[104, 2], edge_index=[2, 180], K=2056.69360352),
#  Data(x=[104, 2], edge_index=[2, 180], K=1667.922485352),
#  Data(x=[104, 2], edge_index=[2, 180], K=1625.4010009760002),
#  Data(x=[104, 2], edge_index=[2, 180], K=1350.8200683599998),
#  Data(x=[104, 2], edge_index=[2, 180], K=1165.021362304),
#  Data(x=[104, 2], edge_index=[2, 180], K=1145.729858398),
#  Data(x=[104, 2], edge_index=[2, 180], K=1526.346557618),
#  Data(x=[104, 2], edge_index=[2, 180], K=1501.656982422),
#  Data(x=[104, 2], edge_index=[2, 180], K=1038.693969726),
#  Data(x=[104, 2], edge_index=[2, 180], K=1944.517578126),
#  Data(x=[104, 2], edge_index=[2, 180], K=1696.5678710939999),
#  Data(x=[104, 2], edge_index=[2, 180], K=1927.415283204),
#  Data(x=[104, 2], edge_index=[2, 180], K=1693.594238282),
#  Data(x=[104, 2], edge_index=[2, 180], K=1364.7890625),
#  Data(x=[104, 2], edge_index=[2, 180], K=1512.0454101560001),
#  Data(x=[104, 2], edge_index=[2, 180], K=1895.91796875),
#  Data(x=[104, 2], edge_index=[2, 180], K=1040.044067382),
#  Data(x=[104, 2], edge_index=[2, 180], K=1425.786621094),
#  Data(x=[104, 2], edge_index=[2, 180], K=1307.1245117180001),
#  Data(x=[104, 2], edge_index=[2, 180], K=1711.739746094),
#  Data(x=[104, 2], edge_index=[2, 180], K=1837.643432618),
#  Data(x=[104, 2], edge_index=[2, 180], K=2127.38012696),
#  Data(x=[104, 2], edge_index=[2, 180], K=1580.87927246),
#  Data(x=[104, 2], edge_index=[2, 180], K=1627.25415039),
#  Data(x=[104, 2], edge_index=[2, 180], K=1666.210205078),
#  Data(x=[104, 2], edge_index=[2, 180], K=1591.650268554),
#  Data(x=[104, 2], edge_index=[2, 180], K=1214.60119629),
#  Data(x=[104, 2], edge_index=[2, 180], K=1888.209716796),
#  Data(x=[104, 2], edge_index=[2, 180], K=1646.8349609380002),
#  Data(x=[104, 2], edge_index=[2, 180], K=1834.50427246),
#  Data(x=[104, 2], edge_index=[2, 180], K=2153.7854004),
#  Data(x=[104, 2], edge_index=[2, 180], K=1945.8315429680001),
#  Data(x=[104, 2], edge_index=[2, 180], K=1940.095458984),
#  Data(x=[104, 2], edge_index=[2, 180], K=1481.58605957),
#  Data(x=[104, 2], edge_index=[2, 180], K=1425.169677734),
#  Data(x=[104, 2], edge_index=[2, 180], K=1626.185913086),
#  Data(x=[104, 2], edge_index=[2, 180], K=1046.804077148),
#  Data(x=[104, 2], edge_index=[2, 180], K=1200.98803711),
#  Data(x=[104, 2], edge_index=[2, 180], K=1553.38256836),
#  Data(x=[104, 2], edge_index=[2, 180], K=1375.504638672),
#  Data(x=[104, 2], edge_index=[2, 180], K=1851.963378906),
#  Data(x=[104, 2], edge_index=[2, 180], K=951.739562988),
#  Data(x=[104, 2], edge_index=[2, 180], K=1151.832885742),
#  Data(x=[104, 2], edge_index=[2, 180], K=1328.5852050780002),
#  Data(x=[104, 2], edge_index=[2, 180], K=1541.3481445319999),
#  Data(x=[104, 2], edge_index=[2, 180], K=1512.5307617180001),
#  Data(x=[104, 2], edge_index=[2, 180], K=1553.154174804),
#  Data(x=[104, 2], edge_index=[2, 180], K=1466.497680664),
#  Data(x=[104, 2], edge_index=[2, 180], K=1296.1362304680001),
#  Data(x=[104, 2], edge_index=[2, 180], K=1361.87072754),
#  Data(x=[104, 2], edge_index=[2, 180], K=1116.350219726),
#  Data(x=[104, 2], edge_index=[2, 180], K=1686.295288086),
#  Data(x=[104, 2], edge_index=[2, 180], K=1364.128173828),
#  Data(x=[104, 2], edge_index=[2, 180], K=1714.9719238280002),
#  Data(x=[104, 2], edge_index=[2, 180], K=1304.138061524),
#  Data(x=[104, 2], edge_index=[2, 180], K=1854.4810791020002),
#  Data(x=[104, 2], edge_index=[2, 180], K=1754.3488769540002),
#  Data(x=[104, 2], edge_index=[2, 180], K=1846.407226562),
#  Data(x=[104, 2], edge_index=[2, 180], K=1715.6207275400002),
#  Data(x=[104, 2], edge_index=[2, 180], K=1566.89868164),
#  Data(x=[104, 2], edge_index=[2, 180], K=2078.7512207),
#  Data(x=[104, 2], edge_index=[2, 180], K=1137.637329102),
#  Data(x=[104, 2], edge_index=[2, 180], K=1569.638305664),
#  Data(x=[104, 2], edge_index=[2, 180], K=1115.885498046),
#  Data(x=[104, 2], edge_index=[2, 180], K=2131.88891602),
#  Data(x=[104, 2], edge_index=[2, 180], K=1593.0733642579999),
#  Data(x=[104, 2], edge_index=[2, 180], K=1861.994506836),
#  Data(x=[104, 2], edge_index=[2, 180], K=783.1426391599999),
#  Data(x=[104, 2], edge_index=[2, 180], K=1560.355957032),
#  Data(x=[104, 2], edge_index=[2, 180], K=836.2847900400001),
#  Data(x=[104, 2], edge_index=[2, 180], K=1877.0238037099998),
#  Data(x=[104, 2], edge_index=[2, 180], K=1561.131591796),
#  Data(x=[104, 2], edge_index=[2, 180], K=2038.3665771400001),
#  Data(x=[104, 2], edge_index=[2, 180], K=1852.234375),
#  Data(x=[104, 2], edge_index=[2, 180], K=1164.160888672),
#  Data(x=[104, 2], edge_index=[2, 180], K=1130.1961669920001),
#  Data(x=[104, 2], edge_index=[2, 180], K=947.269226074),
#  Data(x=[104, 2], edge_index=[2, 180], K=1152.421386718),
#  Data(x=[104, 2], edge_index=[2, 180], K=1454.600585938),
#  Data(x=[104, 2], edge_index=[2, 180], K=1130.87109375),
#  Data(x=[104, 2], edge_index=[2, 180], K=635.045532226),
#  Data(x=[104, 2], edge_index=[2, 180], K=1117.18005371),
#  Data(x=[104, 2], edge_index=[2, 180], K=887.9441528320001),
#  Data(x=[104, 2], edge_index=[2, 180], K=1007.733581542),
#  Data(x=[104, 2], edge_index=[2, 180], K=1891.52331543),
#  Data(x=[104, 2], edge_index=[2, 180], K=1165.102172852),
#  Data(x=[104, 2], edge_index=[2, 180], K=2111.47851562),
#  Data(x=[104, 2], edge_index=[2, 180], K=1374.6372070319999),
#  Data(x=[104, 2], edge_index=[2, 180], K=2147.1796875),
#  Data(x=[104, 2], edge_index=[2, 180], K=1209.538208008),
#  Data(x=[104, 2], edge_index=[2, 180], K=1045.549438476),
#  Data(x=[104, 2], edge_index=[2, 180], K=1091.162841796),
#  Data(x=[104, 2], edge_index=[2, 180], K=1019.800842286),
#  Data(x=[104, 2], edge_index=[2, 180], K=1933.192382812),
#  Data(x=[104, 2], edge_index=[2, 180], K=1325.4926757819999),
#  Data(x=[104, 2], edge_index=[2, 180], K=943.015563964),
#  Data(x=[104, 2], edge_index=[2, 180], K=1521.2755126959999),
#  Data(x=[104, 2], edge_index=[2, 180], K=908.543151856),
#  Data(x=[104, 2], edge_index=[2, 180], K=1079.7012939459999),
#  Data(x=[104, 2], edge_index=[2, 180], K=1794.40991211),
#  Data(x=[104, 2], edge_index=[2, 180], K=1019.273620606),
#  Data(x=[104, 2], edge_index=[2, 180], K=1527.022460938),
#  Data(x=[104, 2], edge_index=[2, 180], K=1664.23840332),
#  Data(x=[104, 2], edge_index=[2, 180], K=1173.635864258),
#  Data(x=[104, 2], edge_index=[2, 180], K=1225.1433105459998),
#  Data(x=[104, 2], edge_index=[2, 180], K=1212.9230957040002),
#  Data(x=[104, 2], edge_index=[2, 180], K=1781.157958984),
#  Data(x=[104, 2], edge_index=[2, 180], K=1170.344726562),
#  Data(x=[104, 2], edge_index=[2, 180], K=1216.5206298819999),
#  Data(x=[104, 2], edge_index=[2, 180], K=937.337768554),
#  Data(x=[104, 2], edge_index=[2, 180], K=1296.736938476),
#  Data(x=[104, 2], edge_index=[2, 180], K=1356.34375),
#  Data(x=[104, 2], edge_index=[2, 180], K=1064.35510254),
#  Data(x=[104, 2], edge_index=[2, 180], K=1972.473510742),
#  Data(x=[104, 2], edge_index=[2, 180], K=1563.3172607420001),
#  Data(x=[104, 2], edge_index=[2, 180], K=1014.55053711),
#  Data(x=[104, 2], edge_index=[2, 180], K=1021.4863281260001),
#  Data(x=[104, 2], edge_index=[2, 180], K=1361.194335938),
#  Data(x=[104, 2], edge_index=[2, 180], K=948.565063476),
#  Data(x=[104, 2], edge_index=[2, 180], K=1727.19946289),
#  Data(x=[104, 2], edge_index=[2, 180], K=1389.178222656),
#  Data(x=[104, 2], edge_index=[2, 180], K=1557.453735352),
#  Data(x=[104, 2], edge_index=[2, 180], K=1164.901245118),
#  Data(x=[104, 2], edge_index=[2, 180], K=1346.3627929680001),
#  Data(x=[104, 2], edge_index=[2, 180], K=1379.369628906),
#  Data(x=[104, 2], edge_index=[2, 180], K=1105.7592773439999),
#  Data(x=[104, 2], edge_index=[2, 180], K=1452.7725830079999),
#  Data(x=[104, 2], edge_index=[2, 180], K=1632.5357666020002),
#  Data(x=[104, 2], edge_index=[2, 180], K=1090.462768554),
#  Data(x=[104, 2], edge_index=[2, 180], K=1062.299072266),
#  Data(x=[104, 2], edge_index=[2, 180], K=1050.502319336),
#  Data(x=[104, 2], edge_index=[2, 180], K=1316.07421875),
#  Data(x=[104, 2], edge_index=[2, 180], K=1237.863769532),
#  Data(x=[104, 2], edge_index=[2, 180], K=1131.700561524),
#  Data(x=[104, 2], edge_index=[2, 180], K=1170.489013672),
#  Data(x=[104, 2], edge_index=[2, 180], K=694.02770996),
#  Data(x=[104, 2], edge_index=[2, 180], K=1420.919799804),
#  Data(x=[104, 2], edge_index=[2, 180], K=1535.0899658199999),
#  Data(x=[104, 2], edge_index=[2, 180], K=1028.344238282),
#  Data(x=[104, 2], edge_index=[2, 180], K=1500.57043457),
#  Data(x=[104, 2], edge_index=[2, 180], K=1131.768310546),
#  Data(x=[104, 2], edge_index=[2, 180], K=2008.6198730400001),
#  Data(x=[104, 2], edge_index=[2, 180], K=814.7335815419999),
#  Data(x=[104, 2], edge_index=[2, 180], K=992.6566162099999),
#  Data(x=[104, 2], edge_index=[2, 180], K=1875.7661132819999),
#  Data(x=[104, 2], edge_index=[2, 180], K=1167.19506836),
#  Data(x=[104, 2], edge_index=[2, 180], K=1364.38244629),
#  Data(x=[104, 2], edge_index=[2, 180], K=1103.296875),
#  Data(x=[104, 2], edge_index=[2, 180], K=1190.6264648439999),
#  Data(x=[104, 2], edge_index=[2, 180], K=1050.58557129),
#  Data(x=[104, 2], edge_index=[2, 180], K=971.600463868),
#  Data(x=[104, 2], edge_index=[2, 180], K=2022.95263672),
#  Data(x=[104, 2], edge_index=[2, 180], K=1251.971923828),
#  Data(x=[104, 2], edge_index=[2, 180], K=1338.09777832),
#  Data(x=[104, 2], edge_index=[2, 180], K=1001.097961426),
#  Data(x=[104, 2], edge_index=[2, 180], K=1497.182617188),
#  Data(x=[104, 2], edge_index=[2, 180], K=1609.638305664),
#  Data(x=[104, 2], edge_index=[2, 180], K=944.033813476),
#  Data(x=[104, 2], edge_index=[2, 180], K=1695.517089844),
#  Data(x=[104, 2], edge_index=[2, 180], K=1065.51586914),
#  Data(x=[104, 2], edge_index=[2, 180], K=1949.6141357420001),
#  Data(x=[104, 2], edge_index=[2, 180], K=866.735046386),
#  Data(x=[104, 2], edge_index=[2, 180], K=1426.256835938),
#  Data(x=[104, 2], edge_index=[2, 180], K=766.876525878),
#  Data(x=[104, 2], edge_index=[2, 180], K=642.715148926),
#  Data(x=[104, 2], edge_index=[2, 180], K=1105.623413086),
#  Data(x=[104, 2], edge_index=[2, 180], K=885.520996094),
#  Data(x=[104, 2], edge_index=[2, 180], K=936.327453614),
#  Data(x=[104, 2], edge_index=[2, 180], K=945.080078126),
#  Data(x=[104, 2], edge_index=[2, 180], K=1198.118530274),
#  Data(x=[104, 2], edge_index=[2, 180], K=925.892700196),
#  Data(x=[104, 2], edge_index=[2, 180], K=888.9215087900001),
#  Data(x=[104, 2], edge_index=[2, 180], K=913.2505493159999),
#  Data(x=[104, 2], edge_index=[2, 180], K=991.743469238),
#  Data(x=[104, 2], edge_index=[2, 180], K=811.300231934),
#  Data(x=[104, 2], edge_index=[2, 180], K=1068.166015624),
#  Data(x=[104, 2], edge_index=[2, 180], K=1526.10974121),
#  Data(x=[104, 2], edge_index=[2, 180], K=1242.147094726),
#  Data(x=[104, 2], edge_index=[2, 180], K=1006.1249389640001),
#  Data(x=[104, 2], edge_index=[2, 180], K=651.191467286),
#  Data(x=[104, 2], edge_index=[2, 180], K=1247.9997558599998),
#  Data(x=[104, 2], edge_index=[2, 180], K=1304.8696289060001),
#  Data(x=[104, 2], edge_index=[2, 180], K=2082.57910156),
#  Data(x=[104, 2], edge_index=[2, 180], K=1469.5606689459999),
#  Data(x=[104, 2], edge_index=[2, 180], K=1077.469726562),
#  Data(x=[104, 2], edge_index=[2, 180], K=974.75769043),
#  Data(x=[104, 2], edge_index=[2, 180], K=1257.1934814459999),
#  Data(x=[104, 2], edge_index=[2, 180], K=1571.072753906),
#  Data(x=[104, 2], edge_index=[2, 180], K=1488.180297852),
#  Data(x=[104, 2], edge_index=[2, 180], K=1238.963500976),
#  Data(x=[104, 2], edge_index=[2, 180], K=1681.6188964839998),
#  Data(x=[104, 2], edge_index=[2, 180], K=1525.934570312),
#  Data(x=[104, 2], edge_index=[2, 180], K=440.570159912),
#  Data(x=[104, 2], edge_index=[2, 180], K=660.363098144),
#  Data(x=[104, 2], edge_index=[2, 180], K=959.627380372),
#  Data(x=[104, 2], edge_index=[2, 180], K=1005.00164795),
#  Data(x=[104, 2], edge_index=[2, 180], K=618.561889648),
#  Data(x=[104, 2], edge_index=[2, 180], K=1263.339355468),
#  Data(x=[104, 2], edge_index=[2, 180], K=1258.2987060540001),
#  Data(x=[104, 2], edge_index=[2, 180], K=1697.663208008),
#  Data(x=[104, 2], edge_index=[2, 180], K=1164.162353516),
#  Data(x=[104, 2], edge_index=[2, 180], K=1707.44897461),
#  Data(x=[104, 2], edge_index=[2, 180], K=797.666748046),
#  Data(x=[104, 2], edge_index=[2, 180], K=1538.270874024),
#  Data(x=[104, 2], edge_index=[2, 180], K=559.1750488280001),
#  Data(x=[104, 2], edge_index=[2, 180], K=1666.6791992180001),
#  Data(x=[104, 2], edge_index=[2, 180], K=1198.467651368),
#  Data(x=[104, 2], edge_index=[2, 180], K=901.289489746),
#  Data(x=[104, 2], edge_index=[2, 180], K=1194.81213379),
#  Data(x=[104, 2], edge_index=[2, 180], K=1566.330688476),
#  Data(x=[104, 2], edge_index=[2, 180], K=1290.654174804),
#  Data(x=[104, 2], edge_index=[2, 180], K=1081.4989013680001),
#  Data(x=[104, 2], edge_index=[2, 180], K=982.6121826179999),
#  Data(x=[104, 2], edge_index=[2, 180], K=1210.545410156),
#  Data(x=[104, 2], edge_index=[2, 180], K=610.20892334),
#  Data(x=[104, 2], edge_index=[2, 180], K=1252.929199218),
#  Data(x=[104, 2], edge_index=[2, 180], K=1359.2136230459998),
#  Data(x=[104, 2], edge_index=[2, 180], K=832.40612793),
#  Data(x=[104, 2], edge_index=[2, 180], K=834.167358398),
#  Data(x=[104, 2], edge_index=[2, 180], K=998.0722656240001),
#  Data(x=[104, 2], edge_index=[2, 180], K=1161.80053711),
#  Data(x=[104, 2], edge_index=[2, 180], K=766.0411376960001),
#  Data(x=[104, 2], edge_index=[2, 180], K=1038.26928711),
#  Data(x=[104, 2], edge_index=[2, 180], K=679.023925782),
#  Data(x=[104, 2], edge_index=[2, 180], K=1272.060424804),
#  Data(x=[104, 2], edge_index=[2, 180], K=1032.512451172),
#  Data(x=[104, 2], edge_index=[2, 180], K=1470.682128906),
#  Data(x=[104, 2], edge_index=[2, 180], K=1327.616210938),
#  Data(x=[104, 2], edge_index=[2, 180], K=1433.014038086),
#  Data(x=[104, 2], edge_index=[2, 180], K=1047.342529296),
#  Data(x=[104, 2], edge_index=[2, 180], K=1140.803955078),
#  Data(x=[104, 2], edge_index=[2, 180], K=1412.380859376),
#  Data(x=[104, 2], edge_index=[2, 180], K=697.910339356),
#  Data(x=[104, 2], edge_index=[2, 180], K=1216.373901368),
#  Data(x=[104, 2], edge_index=[2, 180], K=1802.5065917959998),
#  Data(x=[104, 2], edge_index=[2, 180], K=449.1930542),
#  Data(x=[104, 2], edge_index=[2, 180], K=1452.60131836),
#  Data(x=[104, 2], edge_index=[2, 180], K=1389.075805664),
#  Data(x=[104, 2], edge_index=[2, 180], K=1005.852111816),
#  Data(x=[104, 2], edge_index=[2, 180], K=1532.51208496),
#  Data(x=[104, 2], edge_index=[2, 180], K=1494.985229492),
#  Data(x=[104, 2], edge_index=[2, 180], K=818.191589356),
#  Data(x=[104, 2], edge_index=[2, 180], K=1336.888061524),
#  Data(x=[104, 2], edge_index=[2, 180], K=674.093200684),
#  Data(x=[104, 2], edge_index=[2, 180], K=1184.3020019540002),
#  Data(x=[104, 2], edge_index=[2, 180], K=910.5311279299999),
#  Data(x=[104, 2], edge_index=[2, 180], K=1384.873168946),
#  Data(x=[104, 2], edge_index=[2, 180], K=959.1494140620001),
#  Data(x=[104, 2], edge_index=[2, 180], K=1027.93383789),
#  Data(x=[104, 2], edge_index=[2, 180], K=790.971557618),
#  Data(x=[104, 2], edge_index=[2, 180], K=845.5812377919999),
#  Data(x=[104, 2], edge_index=[2, 180], K=942.077209472),
#  Data(x=[104, 2], edge_index=[2, 180], K=667.110107422),
#  Data(x=[104, 2], edge_index=[2, 180], K=1524.802612304),
#  Data(x=[104, 2], edge_index=[2, 180], K=1090.094482422),
#  Data(x=[104, 2], edge_index=[2, 180], K=1752.4519042959998),
#  Data(x=[104, 2], edge_index=[2, 180], K=1460.139404296),
#  Data(x=[104, 2], edge_index=[2, 180], K=569.481872558),
#  Data(x=[104, 2], edge_index=[2, 180], K=726.789611816),
#  Data(x=[104, 2], edge_index=[2, 180], K=1321.997802734),
#  Data(x=[104, 2], edge_index=[2, 180], K=1399.6301269540002),
#  Data(x=[104, 2], edge_index=[2, 180], K=1418.198486328),
#  Data(x=[104, 2], edge_index=[2, 180], K=981.653747558),
#  Data(x=[104, 2], edge_index=[2, 180], K=921.8559570320001),
#  Data(x=[104, 2], edge_index=[2, 180], K=1166.162963868),
#  Data(x=[104, 2], edge_index=[2, 180], K=932.258911132),
#  Data(x=[104, 2], edge_index=[2, 180], K=1292.48449707),
#  Data(x=[104, 2], edge_index=[2, 180], K=1195.713378906),
#  Data(x=[104, 2], edge_index=[2, 180], K=1432.5893554680001),
#  Data(x=[104, 2], edge_index=[2, 180], K=1238.030517578),
#  Data(x=[104, 2], edge_index=[2, 180], K=1486.686157226),
#  Data(x=[104, 2], edge_index=[2, 180], K=723.028198242),
#  Data(x=[104, 2], edge_index=[2, 180], K=1232.635375976),
#  Data(x=[104, 2], edge_index=[2, 180], K=1344.739013672),
#  Data(x=[104, 2], edge_index=[2, 180], K=908.355041504),
#  Data(x=[104, 2], edge_index=[2, 180], K=1056.986938476),
#  Data(x=[104, 2], edge_index=[2, 180], K=1493.542358398),
#  Data(x=[104, 2], edge_index=[2, 180], K=547.394226074),
#  Data(x=[104, 2], edge_index=[2, 180], K=713.8051147460001),
#  Data(x=[104, 2], edge_index=[2, 180], K=827.4577636719999),
#  Data(x=[104, 2], edge_index=[2, 180], K=1242.791015624),
#  Data(x=[104, 2], edge_index=[2, 180], K=1354.1823730459998),
#  Data(x=[104, 2], edge_index=[2, 180], K=799.661560058),
#  Data(x=[104, 2], edge_index=[2, 180], K=1025.325805664),
#  Data(x=[104, 2], edge_index=[2, 180], K=1004.7156982419999),
#  Data(x=[104, 2], edge_index=[2, 180], K=658.839233398),
#  Data(x=[104, 2], edge_index=[2, 180], K=771.452636718),
#  Data(x=[104, 2], edge_index=[2, 180], K=727.5031127919999),
#  Data(x=[104, 2], edge_index=[2, 180], K=463.35482788),
#  Data(x=[104, 2], edge_index=[2, 180], K=586.626831054),
#  Data(x=[104, 2], edge_index=[2, 180], K=607.505187988),
#  Data(x=[104, 2], edge_index=[2, 180], K=1328.002563476),
#  Data(x=[104, 2], edge_index=[2, 180], K=840.48010254),
#  Data(x=[104, 2], edge_index=[2, 180], K=1303.405395508),
#  Data(x=[104, 2], edge_index=[2, 180], K=890.891906738),
#  Data(x=[104, 2], edge_index=[2, 180], K=1410.423828126),
#  Data(x=[104, 2], edge_index=[2, 180], K=790.791931152),
#  Data(x=[104, 2], edge_index=[2, 180], K=751.5512084960001),
#  Data(x=[104, 2], edge_index=[2, 180], K=1141.274414062),
#  Data(x=[104, 2], edge_index=[2, 180], K=1238.223632812),
#  Data(x=[104, 2], edge_index=[2, 180], K=1019.810913086),
#  Data(x=[104, 2], edge_index=[2, 180], K=571.354064942),
#  Data(x=[104, 2], edge_index=[2, 180], K=856.642700196),
#  Data(x=[104, 2], edge_index=[2, 180], K=1254.590454102),
#  Data(x=[104, 2], edge_index=[2, 180], K=1248.157836914),
#  Data(x=[104, 2], edge_index=[2, 180], K=666.40600586),
#  Data(x=[104, 2], edge_index=[2, 180], K=1211.071289062),
#  Data(x=[104, 2], edge_index=[2, 180], K=1223.30053711),
#  Data(x=[104, 2], edge_index=[2, 180], K=568.047546386),
#  Data(x=[104, 2], edge_index=[2, 180], K=598.423583984),
#  Data(x=[104, 2], edge_index=[2, 180], K=549.134277344),
#  Data(x=[104, 2], edge_index=[2, 180], K=1233.258789062),
#  Data(x=[104, 2], edge_index=[2, 180], K=439.43762207000003),
#  Data(x=[104, 2], edge_index=[2, 180], K=812.734436036),
#  Data(x=[104, 2], edge_index=[2, 180], K=889.959472656),
#  Data(x=[104, 2], edge_index=[2, 180], K=1277.963623046),
#  Data(x=[104, 2], edge_index=[2, 180], K=1042.353027344),
#  Data(x=[104, 2], edge_index=[2, 180], K=835.5773315419999),
#  Data(x=[104, 2], edge_index=[2, 180], K=1093.48046875),
#  Data(x=[104, 2], edge_index=[2, 180], K=970.294128418),
#  Data(x=[104, 2], edge_index=[2, 180], K=1233.0579833979998),
#  Data(x=[104, 2], edge_index=[2, 180], K=1254.349243164),
#  Data(x=[104, 2], edge_index=[2, 180], K=855.4870605460001),
#  Data(x=[104, 2], edge_index=[2, 180], K=421.613067626),
#  Data(x=[104, 2], edge_index=[2, 180], K=836.597839356),
#  Data(x=[104, 2], edge_index=[2, 180], K=1130.459350586),
#  Data(x=[104, 2], edge_index=[2, 180], K=1419.841064454),
#  Data(x=[104, 2], edge_index=[2, 180], K=815.600524902),
#  Data(x=[104, 2], edge_index=[2, 180], K=719.493164062),
#  Data(x=[104, 2], edge_index=[2, 180], K=754.471618652),
#  Data(x=[104, 2], edge_index=[2, 180], K=435.241638184),
#  Data(x=[104, 2], edge_index=[2, 180], K=1335.60571289),
#  Data(x=[104, 2], edge_index=[2, 180], K=1195.810180664),
#  Data(x=[104, 2], edge_index=[2, 180], K=665.438476562),
#  Data(x=[104, 2], edge_index=[2, 180], K=712.1737060539999),
#  Data(x=[104, 2], edge_index=[2, 180], K=711.131530762),
#  Data(x=[104, 2], edge_index=[2, 180], K=571.6664428720001),
#  Data(x=[104, 2], edge_index=[2, 180], K=633.963989258),
#  Data(x=[104, 2], edge_index=[2, 180], K=941.018432618),
#  Data(x=[104, 2], edge_index=[2, 180], K=703.841186524),
#  Data(x=[104, 2], edge_index=[2, 180], K=916.4525146479999),
#  Data(x=[104, 2], edge_index=[2, 180], K=965.950317382),
#  Data(x=[104, 2], edge_index=[2, 180], K=565.975219726),
#  Data(x=[104, 2], edge_index=[2, 180], K=654.289550782),
#  Data(x=[104, 2], edge_index=[2, 180], K=1151.415893554),
#  Data(x=[104, 2], edge_index=[2, 180], K=1103.782836914),
#  Data(x=[104, 2], edge_index=[2, 180], K=737.6524658200001),
#  Data(x=[104, 2], edge_index=[2, 180], K=1531.899536132),
#  Data(x=[104, 2], edge_index=[2, 180], K=735.8176269539999),
#  Data(x=[104, 2], edge_index=[2, 180], K=861.8688964840001),
#  Data(x=[104, 2], edge_index=[2, 180], K=962.560546876),
#  Data(x=[104, 2], edge_index=[2, 180], K=1095.8737792959998),
#  Data(x=[104, 2], edge_index=[2, 180], K=614.09979248),
#  Data(x=[104, 2], edge_index=[2, 180], K=994.584655762),
#  Data(x=[104, 2], edge_index=[2, 180], K=700.315185546),
#  Data(x=[104, 2], edge_index=[2, 180], K=262.489624024),
#  Data(x=[104, 2], edge_index=[2, 180], K=690.51940918),
#  Data(x=[104, 2], edge_index=[2, 180], K=859.9421386719999),
#  Data(x=[104, 2], edge_index=[2, 180], K=987.537658692),
#  Data(x=[104, 2], edge_index=[2, 180], K=370.98410034200003),
#  Data(x=[104, 2], edge_index=[2, 180], K=644.028198242),
#  Data(x=[104, 2], edge_index=[2, 180], K=739.70703125),
#  Data(x=[104, 2], edge_index=[2, 180], K=1219.3507080079999),
#  Data(x=[104, 2], edge_index=[2, 180], K=831.908996582),
#  Data(x=[104, 2], edge_index=[2, 180], K=581.76397705),
#  Data(x=[104, 2], edge_index=[2, 180], K=375.90615844800004),
#  Data(x=[104, 2], edge_index=[2, 180], K=1479.4295654300001),
#  Data(x=[104, 2], edge_index=[2, 180], K=982.71508789),
#  Data(x=[104, 2], edge_index=[2, 180], K=994.2814941400001),
#  Data(x=[104, 2], edge_index=[2, 180], K=830.5045166020001),
#  Data(x=[104, 2], edge_index=[2, 180], K=865.239257812),
#  Data(x=[104, 2], edge_index=[2, 180], K=501.261383056),
#  Data(x=[104, 2], edge_index=[2, 180], K=1067.76953125),
#  Data(x=[104, 2], edge_index=[2, 180], K=978.6548461919999),
#  Data(x=[104, 2], edge_index=[2, 180], K=1052.1297607420001),
#  Data(x=[104, 2], edge_index=[2, 180], K=882.2484741220001),
#  Data(x=[104, 2], edge_index=[2, 180], K=804.4484863280001),
#  Data(x=[104, 2], edge_index=[2, 180], K=1051.936767578),
#  Data(x=[104, 2], edge_index=[2, 180], K=695.47277832),
#  Data(x=[104, 2], edge_index=[2, 180], K=741.859985352),
#  Data(x=[104, 2], edge_index=[2, 180], K=661.719787598),
#  Data(x=[104, 2], edge_index=[2, 180], K=815.000305176),
#  Data(x=[104, 2], edge_index=[2, 180], K=449.583740234),
#  Data(x=[104, 2], edge_index=[2, 180], K=459.09616088800004),
#  Data(x=[104, 2], edge_index=[2, 180], K=511.556121826),
#  Data(x=[104, 2], edge_index=[2, 180], K=550.0769042960001),
#  Data(x=[104, 2], edge_index=[2, 180], K=555.341003418),
#  Data(x=[104, 2], edge_index=[2, 180], K=582.0778808599999),
#  Data(x=[104, 2], edge_index=[2, 180], K=1090.014282226),
#  Data(x=[104, 2], edge_index=[2, 180], K=359.971160888),
#  Data(x=[104, 2], edge_index=[2, 180], K=778.118530274),
#  Data(x=[104, 2], edge_index=[2, 180], K=1187.002441406),
#  Data(x=[104, 2], edge_index=[2, 180], K=1338.622924804),
#  Data(x=[104, 2], edge_index=[2, 180], K=487.32940673800005),
#  Data(x=[104, 2], edge_index=[2, 180], K=468.921783448),
#  Data(x=[104, 2], edge_index=[2, 180], K=297.32189941400003),
#  Data(x=[104, 2], edge_index=[2, 180], K=551.79284668),
#  Data(x=[104, 2], edge_index=[2, 180], K=734.81994629),
#  Data(x=[104, 2], edge_index=[2, 180], K=794.260314942),
#  Data(x=[104, 2], edge_index=[2, 180], K=856.3806152340001),
#  Data(x=[104, 2], edge_index=[2, 180], K=414.221710206),
#  Data(x=[104, 2], edge_index=[2, 180], K=570.218200684),
#  Data(x=[104, 2], edge_index=[2, 180], K=1196.94506836),
#  Data(x=[104, 2], edge_index=[2, 180], K=1052.09362793),
#  Data(x=[104, 2], edge_index=[2, 180], K=880.959594726),
#  Data(x=[104, 2], edge_index=[2, 180], K=755.613342286),
#  Data(x=[104, 2], edge_index=[2, 180], K=863.085754394),
#  Data(x=[104, 2], edge_index=[2, 180], K=509.95178222600003),
#  Data(x=[104, 2], edge_index=[2, 180], K=1049.015625),
#  Data(x=[104, 2], edge_index=[2, 180], K=1019.6420898440001),
#  Data(x=[104, 2], edge_index=[2, 180], K=818.0420532219999),
#  Data(x=[104, 2], edge_index=[2, 180], K=488.004821778),
#  Data(x=[104, 2], edge_index=[2, 180], K=926.9125976560001),
#  Data(x=[104, 2], edge_index=[2, 180], K=651.50567627),
#  Data(x=[104, 2], edge_index=[2, 180], K=986.0752563479999),
#  Data(x=[104, 2], edge_index=[2, 180], K=762.09375),
#  Data(x=[104, 2], edge_index=[2, 180], K=471.88464355400004),
#  Data(x=[104, 2], edge_index=[2, 180], K=304.477722168),
#  Data(x=[104, 2], edge_index=[2, 180], K=410.128356934),
#  Data(x=[104, 2], edge_index=[2, 180], K=583.00378418),
#  Data(x=[104, 2], edge_index=[2, 180], K=491.948608398),
#  Data(x=[104, 2], edge_index=[2, 180], K=542.4428100580001),
#  Data(x=[104, 2], edge_index=[2, 180], K=824.687927246),
#  Data(x=[104, 2], edge_index=[2, 180], K=318.11135864199997),
#  Data(x=[104, 2], edge_index=[2, 180], K=1092.80114746),
#  Data(x=[104, 2], edge_index=[2, 180], K=563.358032226),
#  Data(x=[104, 2], edge_index=[2, 180], K=729.020629882),
#  Data(x=[104, 2], edge_index=[2, 180], K=1296.454711914),
#  Data(x=[104, 2], edge_index=[2, 180], K=839.6556396479999),
#  Data(x=[104, 2], edge_index=[2, 180], K=945.791625976),
#  Data(x=[104, 2], edge_index=[2, 180], K=482.96173095800003),
#  Data(x=[104, 2], edge_index=[2, 180], K=449.880859374),
#  Data(x=[104, 2], edge_index=[2, 180], K=736.72631836),
#  Data(x=[104, 2], edge_index=[2, 180], K=471.23031616199995),
#  Data(x=[104, 2], edge_index=[2, 180], K=923.543701172),
#  Data(x=[104, 2], edge_index=[2, 180], K=1053.94909668),
#  Data(x=[104, 2], edge_index=[2, 180], K=848.71661377),
#  Data(x=[104, 2], edge_index=[2, 180], K=1186.1809082040002),
#  Data(x=[104, 2], edge_index=[2, 180], K=1003.5961914060001),
#  Data(x=[104, 2], edge_index=[2, 180], K=1053.3100585939999),
#  Data(x=[104, 2], edge_index=[2, 180], K=920.3764038080001),
#  Data(x=[104, 2], edge_index=[2, 180], K=669.099060058),
#  Data(x=[104, 2], edge_index=[2, 180], K=448.87588501),
#  Data(x=[104, 2], edge_index=[2, 180], K=413.942504882),
#  Data(x=[104, 2], edge_index=[2, 180], K=391.713531494),
#  Data(x=[104, 2], edge_index=[2, 180], K=787.53894043),
#  Data(x=[104, 2], edge_index=[2, 180], K=864.4234619140001),
#  Data(x=[104, 2], edge_index=[2, 180], K=445.212310792),
#  Data(x=[104, 2], edge_index=[2, 180], K=301.083953858),
#  Data(x=[104, 2], edge_index=[2, 180], K=889.2969360359999),
#  Data(x=[104, 2], edge_index=[2, 180], K=493.58560180600006),
#  Data(x=[104, 2], edge_index=[2, 180], K=1190.391723632),
#  Data(x=[104, 2], edge_index=[2, 180], K=1020.23272705),
#  Data(x=[104, 2], edge_index=[2, 180], K=848.983093262),
#  Data(x=[104, 2], edge_index=[2, 180], K=569.8984375),
#  Data(x=[104, 2], edge_index=[2, 180], K=652.616516114),
#  Data(x=[104, 2], edge_index=[2, 180], K=1245.206176758),
#  Data(x=[104, 2], edge_index=[2, 180], K=683.2653808599999),
#  Data(x=[104, 2], edge_index=[2, 180], K=604.7265625),
#  Data(x=[104, 2], edge_index=[2, 180], K=516.458862304),
#  Data(x=[104, 2], edge_index=[2, 180], K=396.00573730400004),
#  Data(x=[104, 2], edge_index=[2, 180], K=947.67010498),
#  Data(x=[104, 2], edge_index=[2, 180], K=611.3729858400001),
#  Data(x=[104, 2], edge_index=[2, 180], K=1074.576416016),
#  Data(x=[104, 2], edge_index=[2, 180], K=738.13470459),
#  Data(x=[104, 2], edge_index=[2, 180], K=1277.794921874),
#  Data(x=[104, 2], edge_index=[2, 180], K=840.493713378),
#  Data(x=[104, 2], edge_index=[2, 180], K=525.99572754),
#  Data(x=[104, 2], edge_index=[2, 180], K=935.867736816),
#  Data(x=[104, 2], edge_index=[2, 180], K=632.270935058),
#  Data(x=[104, 2], edge_index=[2, 180], K=826.766845704),
#  Data(x=[104, 2], edge_index=[2, 180], K=333.091156006),
#  Data(x=[104, 2], edge_index=[2, 180], K=569.703918458),
#  Data(x=[104, 2], edge_index=[2, 180], K=353.61743164),
#  Data(x=[104, 2], edge_index=[2, 180], K=488.96597290000005),
#  Data(x=[104, 2], edge_index=[2, 180], K=721.984680176),
#  Data(x=[104, 2], edge_index=[2, 180], K=701.26928711),
#  Data(x=[104, 2], edge_index=[2, 180], K=882.4602050780001),
#  Data(x=[104, 2], edge_index=[2, 180], K=169.20384216300002),
#  Data(x=[104, 2], edge_index=[2, 180], K=494.807128906),
#  Data(x=[104, 2], edge_index=[2, 180], K=354.935668946),
#  Data(x=[104, 2], edge_index=[2, 180], K=772.561706542),
#  Data(x=[104, 2], edge_index=[2, 180], K=245.72390747),
#  Data(x=[104, 2], edge_index=[2, 180], K=569.25616455),
#  Data(x=[104, 2], edge_index=[2, 180], K=414.62973022399996),
#  Data(x=[104, 2], edge_index=[2, 180], K=833.32043457),
#  Data(x=[104, 2], edge_index=[2, 180], K=704.364501954),
#  Data(x=[104, 2], edge_index=[2, 180], K=748.186096192),
#  Data(x=[104, 2], edge_index=[2, 180], K=271.608093262),
#  Data(x=[104, 2], edge_index=[2, 180], K=381.62463379),
#  Data(x=[104, 2], edge_index=[2, 180], K=552.319335938),
#  Data(x=[104, 2], edge_index=[2, 180], K=768.250793458),
#  Data(x=[104, 2], edge_index=[2, 180], K=379.098480224),
#  Data(x=[104, 2], edge_index=[2, 180], K=576.319396972),
#  Data(x=[104, 2], edge_index=[2, 180], K=991.4509277340001),
#  Data(x=[104, 2], edge_index=[2, 180], K=652.360412598),
#  Data(x=[104, 2], edge_index=[2, 180], K=364.153137208),
#  Data(x=[104, 2], edge_index=[2, 180], K=520.526367188),
#  Data(x=[104, 2], edge_index=[2, 180], K=496.59393310599995),
#  Data(x=[104, 2], edge_index=[2, 180], K=525.5552978520001),
#  Data(x=[104, 2], edge_index=[2, 180], K=369.850341796),
#  Data(x=[104, 2], edge_index=[2, 180], K=580.4686889640001),
#  Data(x=[104, 2], edge_index=[2, 180], K=783.9431152340001),
#  Data(x=[104, 2], edge_index=[2, 180], K=312.73049926799996),
#  Data(x=[104, 2], edge_index=[2, 180], K=665.0469360359999),
#  Data(x=[104, 2], edge_index=[2, 180], K=516.0287475580001),
#  Data(x=[104, 2], edge_index=[2, 180], K=457.628936768),
#  Data(x=[104, 2], edge_index=[2, 180], K=717.351379394),
#  Data(x=[104, 2], edge_index=[2, 180], K=668.30255127),
#  Data(x=[104, 2], edge_index=[2, 180], K=414.61083984399994),
#  Data(x=[104, 2], edge_index=[2, 180], K=633.806213378),
#  Data(x=[104, 2], edge_index=[2, 180], K=222.30693054199998),
#  Data(x=[104, 2], edge_index=[2, 180], K=475.339447022),
#  Data(x=[104, 2], edge_index=[2, 180], K=522.660888672),
#  Data(x=[104, 2], edge_index=[2, 180], K=775.766845704),
#  Data(x=[104, 2], edge_index=[2, 180], K=470.382263184),
#  Data(x=[104, 2], edge_index=[2, 180], K=670.003723144),
#  Data(x=[104, 2], edge_index=[2, 180], K=344.6534729),
#  Data(x=[104, 2], edge_index=[2, 180], K=357.70739746000004),
#  Data(x=[104, 2], edge_index=[2, 180], K=421.94616699200003),
#  Data(x=[104, 2], edge_index=[2, 180], K=315.990753174),
#  Data(x=[104, 2], edge_index=[2, 180], K=450.399719238),
#  Data(x=[104, 2], edge_index=[2, 180], K=1054.55078125),
#  Data(x=[104, 2], edge_index=[2, 180], K=711.62145996),
#  Data(x=[104, 2], edge_index=[2, 180], K=518.221557618),
#  Data(x=[104, 2], edge_index=[2, 180], K=1043.91027832),
#  Data(x=[104, 2], edge_index=[2, 180], K=795.5310668940001),
#  Data(x=[104, 2], edge_index=[2, 180], K=293.19488525400004),
#  Data(x=[104, 2], edge_index=[2, 180], K=635.871826172),
#  Data(x=[104, 2], edge_index=[2, 180], K=674.0752563479999),
#  Data(x=[104, 2], edge_index=[2, 180], K=651.0841674799999),
#  Data(x=[104, 2], edge_index=[2, 180], K=912.611572266),
#  Data(x=[104, 2], edge_index=[2, 180], K=585.473815918),
#  Data(x=[104, 2], edge_index=[2, 180], K=727.793884278),
#  Data(x=[104, 2], edge_index=[2, 180], K=473.918640136),
#  Data(x=[104, 2], edge_index=[2, 180], K=568.109436036),
#  Data(x=[104, 2], edge_index=[2, 180], K=490.153747558),
#  Data(x=[104, 2], edge_index=[2, 180], K=214.487670898),
#  Data(x=[104, 2], edge_index=[2, 180], K=931.1072387700001),
#  Data(x=[104, 2], edge_index=[2, 180], K=467.095153808),
#  Data(x=[104, 2], edge_index=[2, 180], K=771.696350098),
#  Data(x=[104, 2], edge_index=[2, 180], K=459.454071044),
#  Data(x=[104, 2], edge_index=[2, 180], K=519.53137207),
#  Data(x=[104, 2], edge_index=[2, 180], K=487.319213868),
#  Data(x=[104, 2], edge_index=[2, 180], K=545.852478028),
#  Data(x=[104, 2], edge_index=[2, 180], K=252.238357544),
#  Data(x=[104, 2], edge_index=[2, 180], K=719.074279786),
#  Data(x=[104, 2], edge_index=[2, 180], K=434.93164062600005),
#  Data(x=[104, 2], edge_index=[2, 180], K=600.477905274),
#  Data(x=[104, 2], edge_index=[2, 180], K=450.51248169),
#  Data(x=[104, 2], edge_index=[2, 180], K=295.10256958),
#  Data(x=[104, 2], edge_index=[2, 180], K=407.757415772),
#  Data(x=[104, 2], edge_index=[2, 180], K=605.7689819340001),
#  Data(x=[104, 2], edge_index=[2, 180], K=280.921478272),
#  Data(x=[104, 2], edge_index=[2, 180], K=255.219604492),
#  Data(x=[104, 2], edge_index=[2, 180], K=428.645751954),
#  Data(x=[104, 2], edge_index=[2, 180], K=235.89019775399998),
#  Data(x=[104, 2], edge_index=[2, 180], K=384.848510742),
#  Data(x=[104, 2], edge_index=[2, 180], K=526.161621094),
#  Data(x=[104, 2], edge_index=[2, 180], K=216.84046936),
#  Data(x=[104, 2], edge_index=[2, 180], K=730.1592407219999),
#  Data(x=[104, 2], edge_index=[2, 180], K=604.340515136),
#  Data(x=[104, 2], edge_index=[2, 180], K=222.09759521400002),
#  Data(x=[104, 2], edge_index=[2, 180], K=855.2655029299999),
#  Data(x=[104, 2], edge_index=[2, 180], K=802.6630249020001),
#  Data(x=[104, 2], edge_index=[2, 180], K=335.522888184),
#  Data(x=[104, 2], edge_index=[2, 180], K=465.749023438),
#  Data(x=[104, 2], edge_index=[2, 180], K=603.709960938),
#  Data(x=[104, 2], edge_index=[2, 180], K=723.721191406),
#  Data(x=[104, 2], edge_index=[2, 180], K=705.013000488),
#  Data(x=[104, 2], edge_index=[2, 180], K=790.705322266),
#  Data(x=[104, 2], edge_index=[2, 180], K=935.6141967780001),
#  Data(x=[104, 2], edge_index=[2, 180], K=925.6358642580001),
#  Data(x=[104, 2], edge_index=[2, 180], K=240.48298645),
#  Data(x=[104, 2], edge_index=[2, 180], K=258.05456543),
#  Data(x=[104, 2], edge_index=[2, 180], K=174.5664978028),
#  Data(x=[104, 2], edge_index=[2, 180], K=489.62945556599993),
#  Data(x=[104, 2], edge_index=[2, 180], K=844.572753906),
#  Data(x=[104, 2], edge_index=[2, 180], K=629.036560058),
#  Data(x=[104, 2], edge_index=[2, 180], K=755.773498536),
#  Data(x=[104, 2], edge_index=[2, 180], K=292.13470459),
#  Data(x=[104, 2], edge_index=[2, 180], K=794.016601562),
#  Data(x=[104, 2], edge_index=[2, 180], K=283.19595337000004),
#  Data(x=[104, 2], edge_index=[2, 180], K=536.596618652),
#  Data(x=[104, 2], edge_index=[2, 180], K=829.6276245120001),
#  Data(x=[104, 2], edge_index=[2, 180], K=587.282470704),
#  Data(x=[104, 2], edge_index=[2, 180], K=443.647491456),
#  Data(x=[104, 2], edge_index=[2, 180], K=796.045654296),
#  Data(x=[104, 2], edge_index=[2, 180], K=830.306274414),
#  Data(x=[104, 2], edge_index=[2, 180], K=550.389038086),
#  Data(x=[104, 2], edge_index=[2, 180], K=472.958892822),
#  Data(x=[104, 2], edge_index=[2, 180], K=338.31564331),
#  Data(x=[104, 2], edge_index=[2, 180], K=460.03924560599995),
#  Data(x=[104, 2], edge_index=[2, 180], K=482.78634643600003),
#  Data(x=[104, 2], edge_index=[2, 180], K=553.804626464),
#  Data(x=[104, 2], edge_index=[2, 180], K=516.924865722),
#  Data(x=[104, 2], edge_index=[2, 180], K=395.17739868200005),
#  Data(x=[104, 2], edge_index=[2, 180], K=517.807434082),
#  Data(x=[104, 2], edge_index=[2, 180], K=472.692504882),
#  Data(x=[104, 2], edge_index=[2, 180], K=420.512237548),
#  Data(x=[104, 2], edge_index=[2, 180], K=509.1539917),
#  Data(x=[104, 2], edge_index=[2, 180], K=746.820922852),
#  Data(x=[104, 2], edge_index=[2, 180], K=760.108886718),
#  Data(x=[104, 2], edge_index=[2, 180], K=555.193359374),
#  Data(x=[104, 2], edge_index=[2, 180], K=342.63568115199996),
#  Data(x=[104, 2], edge_index=[2, 180], K=635.788757324),
#  Data(x=[104, 2], edge_index=[2, 180], K=576.090515136),
#  Data(x=[104, 2], edge_index=[2, 180], K=408.80499267600004),
#  Data(x=[104, 2], edge_index=[2, 180], K=334.567504882),
#  Data(x=[104, 2], edge_index=[2, 180], K=977.786254882),
#  Data(x=[104, 2], edge_index=[2, 180], K=157.6051177978),
#  Data(x=[104, 2], edge_index=[2, 180], K=470.26889038),
#  Data(x=[104, 2], edge_index=[2, 180], K=373.036834716),
#  Data(x=[104, 2], edge_index=[2, 180], K=664.6353759760001),
#  Data(x=[104, 2], edge_index=[2, 180], K=851.641540528),
#  Data(x=[104, 2], edge_index=[2, 180], K=510.410827636),
#  Data(x=[104, 2], edge_index=[2, 180], K=655.546936036),
#  Data(x=[104, 2], edge_index=[2, 180], K=600.464355468),
#  Data(x=[104, 2], edge_index=[2, 180], K=571.740478516),
#  Data(x=[104, 2], edge_index=[2, 180], K=533.883728028),
#  Data(x=[104, 2], edge_index=[2, 180], K=913.118041992),
#  Data(x=[104, 2], edge_index=[2, 180], K=257.31515503),
#  Data(x=[104, 2], edge_index=[2, 180], K=542.477600098),
#  Data(x=[104, 2], edge_index=[2, 180], K=312.281188964),
#  Data(x=[104, 2], edge_index=[2, 180], K=325.168029786),
#  Data(x=[104, 2], edge_index=[2, 180], K=493.57971191400003),
#  Data(x=[104, 2], edge_index=[2, 180], K=440.497406006),
#  Data(x=[104, 2], edge_index=[2, 180], K=291.324249268),
#  Data(x=[104, 2], edge_index=[2, 180], K=393.57946777399997),
#  Data(x=[104, 2], edge_index=[2, 180], K=790.645751954),
#  Data(x=[104, 2], edge_index=[2, 180], K=334.11227417),
#  Data(x=[104, 2], edge_index=[2, 180], K=665.259094238),
#  Data(x=[104, 2], edge_index=[2, 180], K=204.97180175799997),
#  Data(x=[104, 2], edge_index=[2, 180], K=483.740112304),
#  Data(x=[104, 2], edge_index=[2, 180], K=689.62097168),
#  Data(x=[104, 2], edge_index=[2, 180], K=218.735656738),
#  Data(x=[104, 2], edge_index=[2, 180], K=186.07788085939998),
#  Data(x=[104, 2], edge_index=[2, 180], K=402.09451294),
#  Data(x=[104, 2], edge_index=[2, 180], K=715.2997436520001),
#  Data(x=[104, 2], edge_index=[2, 180], K=314.577972412),
#  Data(x=[104, 2], edge_index=[2, 180], K=828.740783692),
#  Data(x=[104, 2], edge_index=[2, 180], K=530.280517578),
#  Data(x=[104, 2], edge_index=[2, 180], K=277.64587402399997),
#  Data(x=[104, 2], edge_index=[2, 180], K=726.46673584),
#  Data(x=[104, 2], edge_index=[2, 180], K=328.77420044),
#  Data(x=[104, 2], edge_index=[2, 180], K=663.3231201179999),
#  Data(x=[104, 2], edge_index=[2, 180], K=461.116241456),
#  Data(x=[104, 2], edge_index=[2, 180], K=575.880310058),
#  Data(x=[104, 2], edge_index=[2, 180], K=781.4075927739999),
#  Data(x=[104, 2], edge_index=[2, 180], K=391.39678954999994),
#  Data(x=[104, 2], edge_index=[2, 180], K=276.095825196),
#  Data(x=[104, 2], edge_index=[2, 180], K=268.60913086),
#  Data(x=[104, 2], edge_index=[2, 180], K=1059.904785156),
#  Data(x=[104, 2], edge_index=[2, 180], K=297.47644043),
#  Data(x=[104, 2], edge_index=[2, 180], K=362.159759522),
#  Data(x=[104, 2], edge_index=[2, 180], K=294.81930542),
#  Data(x=[104, 2], edge_index=[2, 180], K=762.85357666),
#  Data(x=[104, 2], edge_index=[2, 180], K=758.40222168),
#  Data(x=[104, 2], edge_index=[2, 180], K=325.87121582),
#  Data(x=[104, 2], edge_index=[2, 180], K=394.25778198200004),
#  Data(x=[104, 2], edge_index=[2, 180], K=456.42050170799996),
#  Data(x=[104, 2], edge_index=[2, 180], K=559.645202636),
#  Data(x=[104, 2], edge_index=[2, 180], K=191.70570373540002),
#  Data(x=[104, 2], edge_index=[2, 180], K=434.46633911199996),
#  Data(x=[104, 2], edge_index=[2, 180], K=1224.805664062),
#  Data(x=[104, 2], edge_index=[2, 180], K=212.350784302),
#  Data(x=[104, 2], edge_index=[2, 180], K=493.954742432),
#  Data(x=[104, 2], edge_index=[2, 180], K=520.21496582),
#  Data(x=[104, 2], edge_index=[2, 180], K=428.672302246),
#  Data(x=[104, 2], edge_index=[2, 180], K=538.377075196),
#  Data(x=[104, 2], edge_index=[2, 180], K=523.8970947260001),
#  Data(x=[104, 2], edge_index=[2, 180], K=283.607574462),
#  Data(x=[104, 2], edge_index=[2, 180], K=527.367980958),
#  Data(x=[104, 2], edge_index=[2, 180], K=395.174713134),
#  Data(x=[104, 2], edge_index=[2, 180], K=420.3414917),
#  Data(x=[104, 2], edge_index=[2, 180], K=422.726867676),
#  Data(x=[104, 2], edge_index=[2, 180], K=447.568328858),
#  Data(x=[104, 2], edge_index=[2, 180], K=628.4304809580001),
#  Data(x=[104, 2], edge_index=[2, 180], K=300.38131713800004),
#  Data(x=[104, 2], edge_index=[2, 180], K=698.901306152),
#  Data(x=[104, 2], edge_index=[2, 180], K=199.6488494874),
#  Data(x=[104, 2], edge_index=[2, 180], K=746.341796876),
#  Data(x=[104, 2], edge_index=[2, 180], K=593.028503418),
#  Data(x=[104, 2], edge_index=[2, 180], K=254.83445739799998),
#  Data(x=[104, 2], edge_index=[2, 180], K=294.303192138),
#  Data(x=[104, 2], edge_index=[2, 180], K=414.88262939400005),
#  Data(x=[104, 2], edge_index=[2, 180], K=824.6994628900001),
#  ...]

# %%
batch_size = args.batch_num
epoch_num = args.epoch_num 
learning_rate = 0.001
overlap=args.overlap

# Check if the graph data is directed or undirected. For this study, undirected edges are used.
all_undirected_before = all(is_undirected(data) for data in dataset)
print(f'Graphs are undirected (before conversion): {all_undirected_before}')  # True if all are undirected, False otherwise

# Convert all graphs in the dataset to undirected
dataset = [make_undirected(data) for data in dataset]

# Re-check if all graphs are now undirected
all_undirected_after = all(is_undirected(data) for data in dataset)
print(f'Graphs are undirected (after conversion): {all_undirected_after}')  # True if all are undirected, False otherwise

dataset = normalize_planar_info(dataset)

# Split dataset for train/validation/test
train_loader, test_loader, valid_loader = prepare_dataset(dataset, batch_size, train_percentage=0.80, test_percentage=0.1)
# Out:
# Graphs are undirected (before conversion): False
# Graphs are undirected (after conversion): True
# Number of training graphs: 4004
# Number of test graphs: 500
# Number of vali graphs: 501

# %%
dataset[0]
# Out:
# Data(x=[104, 2], edge_index=[2, 360], K=3334.25610352)

# %% [markdown]
# # GNN architecture

# %%
# Define the model, optimizer, and loss function

no_node_feature = dataset[0].x.shape[1]
model = GIN(dim_h=64, node_feature=no_node_feature)
optimizer = torch.optim.Adam(model.parameters(), lr=learning_rate, weight_decay=1e-4)
criterion = nn.MSELoss()
print(model)

# Define a learning rate scheduler
scheduler = optim.lr_scheduler.ReduceLROnPlateau(optimizer, mode='min', patience=5, factor=0.5, verbose=True)

# Use GPU if available, otherwise use CPU
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
model.to(device)

num_params = sum(p.numel() for p in model.parameters())
print("Number of parameters:", num_params)
# Out:
# GIN(
#   (conv1): GINConv(nn=Sequential(
#     (0): Linear(in_features=2, out_features=64, bias=True)
#     (1): BatchNorm1d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (2): ReLU()
#     (3): Linear(in_features=64, out_features=64, bias=True)
#     (4): ReLU()
#   ))
#   (conv2): GINConv(nn=Sequential(
#     (0): Linear(in_features=64, out_features=64, bias=True)
#     (1): BatchNorm1d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (2): ReLU()
#     (3): Linear(in_features=64, out_features=64, bias=True)
#     (4): ReLU()
#   ))
#   (conv3): GINConv(nn=Sequential(
#     (0): Linear(in_features=64, out_features=64, bias=True)
#     (1): BatchNorm1d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (2): ReLU()
#     (3): Linear(in_features=64, out_features=64, bias=True)
#     (4): ReLU()
#   ))
#   (lin1): Linear(in_features=192, out_features=128, bias=True)
#   (lin2): Linear(in_features=128, out_features=128, bias=True)
#   (lin4): Linear(in_features=128, out_features=1, bias=True)
#   (relu): ReLU()
# )
# Number of parameters: 62721
# /root/miniconda3/envs/GNN_ElasticModulus_Prediction/lib/python3.9/site-packages/torch/optim/lr_scheduler.py:62: UserWarning: The verbose parameter is deprecated. Please use get_last_lr() to access the learning rate.
#   warnings.warn(

# %% [markdown]
# ## Training

# %%
train_losses, test_losses, R2_trainings, R2_tests, best_state_dict = train_model(
    model, train_loader, test_loader, criterion, optimizer, scheduler, device=device, num_epochs=epoch_num)
# Out:
# Epoch [1], Loss[Train: 1608004.643, Test: 535825.100], R2[Train: -0.466, Test: 0.487]
# Epoch [2], Loss[Train: 333893.491, Test: 345364.834], R2[Train: 0.696, Test: 0.669]
# Epoch [3], Loss[Train: 305831.479, Test: 397428.947], R2[Train: 0.721, Test: 0.619]
# Epoch [4], Loss[Train: 302172.092, Test: 352823.231], R2[Train: 0.725, Test: 0.662]
# Epoch [5], Loss[Train: 294133.763, Test: 287351.329], R2[Train: 0.732, Test: 0.725]
# Epoch [6], Loss[Train: 272040.661, Test: 287132.646], R2[Train: 0.752, Test: 0.725]
# Epoch [7], Loss[Train: 263699.281, Test: 306275.925], R2[Train: 0.760, Test: 0.707]
# Epoch [8], Loss[Train: 290254.720, Test: 271824.960], R2[Train: 0.735, Test: 0.740]
# Epoch [9], Loss[Train: 278180.695, Test: 289799.315], R2[Train: 0.746, Test: 0.722]
# Epoch [10], Loss[Train: 239640.567, Test: 307334.084], R2[Train: 0.782, Test: 0.706]
# Epoch [11], Loss[Train: 255921.160, Test: 295827.099], R2[Train: 0.767, Test: 0.717]
# Epoch [12], Loss[Train: 234264.832, Test: 253305.609], R2[Train: 0.786, Test: 0.757]
# Epoch [13], Loss[Train: 236346.258, Test: 279846.155], R2[Train: 0.785, Test: 0.732]
# Epoch [14], Loss[Train: 242740.835, Test: 251562.407], R2[Train: 0.779, Test: 0.759]
# Epoch [15], Loss[Train: 231041.347, Test: 264410.735], R2[Train: 0.789, Test: 0.747]
# Epoch [16], Loss[Train: 210036.079, Test: 244407.152], R2[Train: 0.809, Test: 0.766]
# Epoch [17], Loss[Train: 231143.289, Test: 227509.109], R2[Train: 0.789, Test: 0.782]
# Epoch [18], Loss[Train: 226963.357, Test: 238286.118], R2[Train: 0.793, Test: 0.772]
# Epoch [19], Loss[Train: 196905.182, Test: 207178.972], R2[Train: 0.821, Test: 0.802]
# Epoch [20], Loss[Train: 201548.165, Test: 364684.421], R2[Train: 0.816, Test: 0.651]
# Epoch [21], Loss[Train: 182609.087, Test: 170753.070], R2[Train: 0.834, Test: 0.836]
# Epoch [22], Loss[Train: 202502.112, Test: 171222.992], R2[Train: 0.815, Test: 0.836]
# Epoch [23], Loss[Train: 170456.460, Test: 162323.266], R2[Train: 0.845, Test: 0.844]
# Epoch [24], Loss[Train: 194731.164, Test: 572130.175], R2[Train: 0.823, Test: 0.452]
# Epoch [25], Loss[Train: 177376.727, Test: 152693.527], R2[Train: 0.838, Test: 0.854]
# Epoch [26], Loss[Train: 158422.477, Test: 163165.786], R2[Train: 0.856, Test: 0.844]
# Epoch [27], Loss[Train: 131666.748, Test: 125327.183], R2[Train: 0.880, Test: 0.880]
# Epoch [28], Loss[Train: 237311.747, Test: 148518.602], R2[Train: 0.784, Test: 0.858]
# Epoch [29], Loss[Train: 154283.008, Test: 130301.314], R2[Train: 0.859, Test: 0.875]
# Epoch [30], Loss[Train: 140433.884, Test: 133427.396], R2[Train: 0.872, Test: 0.872]
# Epoch [31], Loss[Train: 151486.036, Test: 132252.260], R2[Train: 0.862, Test: 0.873]
# Epoch [32], Loss[Train: 126590.331, Test: 158554.516], R2[Train: 0.885, Test: 0.848]
# Epoch [33], Loss[Train: 142658.742, Test: 209502.826], R2[Train: 0.870, Test: 0.799]
# Epoch [34], Loss[Train: 149346.081, Test: 224471.441], R2[Train: 0.864, Test: 0.785]
# Epoch [35], Loss[Train: 125003.273, Test: 136934.445], R2[Train: 0.886, Test: 0.869]
# Epoch [36], Loss[Train: 162746.474, Test: 184296.080], R2[Train: 0.852, Test: 0.823]
# Epoch [37], Loss[Train: 179932.124, Test: 137031.894], R2[Train: 0.836, Test: 0.869]
# Epoch [38], Loss[Train: 151418.729, Test: 128272.947], R2[Train: 0.862, Test: 0.877]
# Epoch [39], Loss[Train: 150877.480, Test: 162733.634], R2[Train: 0.862, Test: 0.844]
# Epoch [40], Loss[Train: 129779.250, Test: 141379.401], R2[Train: 0.882, Test: 0.865]
# Epoch [41], Loss[Train: 138322.750, Test: 204318.144], R2[Train: 0.874, Test: 0.804]
# Epoch [42], Loss[Train: 118970.130, Test: 171071.916], R2[Train: 0.892, Test: 0.836]
# Epoch [43], Loss[Train: 113337.612, Test: 132621.109], R2[Train: 0.897, Test: 0.873]
# Epoch [44], Loss[Train: 110504.874, Test: 122141.200], R2[Train: 0.899, Test: 0.883]
# Epoch [45], Loss[Train: 110000.294, Test: 136471.689], R2[Train: 0.900, Test: 0.869]
# Epoch [46], Loss[Train: 103956.926, Test: 146508.325], R2[Train: 0.905, Test: 0.860]
# Epoch [47], Loss[Train: 119115.835, Test: 123664.824], R2[Train: 0.891, Test: 0.882]
# Epoch [48], Loss[Train: 101695.786, Test: 157673.371], R2[Train: 0.907, Test: 0.849]
# Epoch [49], Loss[Train: 105316.719, Test: 115819.879], R2[Train: 0.904, Test: 0.889]
# Epoch [50], Loss[Train: 110021.504, Test: 114956.043], R2[Train: 0.900, Test: 0.890]
# Epoch [51], Loss[Train: 101979.241, Test: 130699.094], R2[Train: 0.907, Test: 0.875]
# Epoch [52], Loss[Train: 111907.907, Test: 116448.074], R2[Train: 0.898, Test: 0.888]
# Epoch [53], Loss[Train: 99667.982, Test: 137793.947], R2[Train: 0.909, Test: 0.868]
# Epoch [54], Loss[Train: 130200.656, Test: 109392.325], R2[Train: 0.881, Test: 0.895]
# Epoch [55], Loss[Train: 103469.215, Test: 199960.048], R2[Train: 0.906, Test: 0.808]
# Epoch [56], Loss[Train: 121374.194, Test: 117251.623], R2[Train: 0.889, Test: 0.888]
# Epoch [57], Loss[Train: 102354.185, Test: 111274.587], R2[Train: 0.907, Test: 0.893]
# Epoch [58], Loss[Train: 94323.773, Test: 138733.986], R2[Train: 0.914, Test: 0.867]
# Epoch [59], Loss[Train: 124124.690, Test: 108505.950], R2[Train: 0.887, Test: 0.896]
# Epoch [60], Loss[Train: 99953.051, Test: 133214.655], R2[Train: 0.909, Test: 0.872]
# Epoch [61], Loss[Train: 113284.610, Test: 120819.152], R2[Train: 0.897, Test: 0.884]
# Epoch [62], Loss[Train: 97633.563, Test: 144929.464], R2[Train: 0.911, Test: 0.861]
# Epoch [63], Loss[Train: 121482.996, Test: 110759.471], R2[Train: 0.889, Test: 0.894]
# Epoch [64], Loss[Train: 97608.872, Test: 173695.921], R2[Train: 0.911, Test: 0.834]
# Epoch [65], Loss[Train: 96356.306, Test: 109158.916], R2[Train: 0.912, Test: 0.895]
# Epoch [66], Loss[Train: 89469.680, Test: 129555.326], R2[Train: 0.918, Test: 0.876]
# Epoch [67], Loss[Train: 98204.109, Test: 110513.118], R2[Train: 0.910, Test: 0.894]
# Epoch [68], Loss[Train: 96024.273, Test: 109538.819], R2[Train: 0.912, Test: 0.895]
# Epoch [69], Loss[Train: 105069.896, Test: 119413.656], R2[Train: 0.904, Test: 0.886]
# Epoch [70], Loss[Train: 91760.904, Test: 110489.899], R2[Train: 0.916, Test: 0.894]
# Epoch [71], Loss[Train: 86627.274, Test: 114334.107], R2[Train: 0.921, Test: 0.890]
# Epoch [72], Loss[Train: 94902.476, Test: 159526.487], R2[Train: 0.913, Test: 0.847]
# Epoch [73], Loss[Train: 91088.239, Test: 111935.118], R2[Train: 0.917, Test: 0.893]
# Epoch [74], Loss[Train: 89415.564, Test: 108749.777], R2[Train: 0.918, Test: 0.896]
# Epoch [75], Loss[Train: 92374.122, Test: 108554.520], R2[Train: 0.916, Test: 0.896]
# Epoch [76], Loss[Train: 93874.244, Test: 118458.618], R2[Train: 0.914, Test: 0.887]
# Epoch [77], Loss[Train: 85867.264, Test: 115794.597], R2[Train: 0.922, Test: 0.889]
# Epoch [78], Loss[Train: 84445.233, Test: 116561.651], R2[Train: 0.923, Test: 0.888]
# Epoch [79], Loss[Train: 88355.299, Test: 115442.287], R2[Train: 0.919, Test: 0.889]
# Epoch [80], Loss[Train: 88957.040, Test: 107813.813], R2[Train: 0.919, Test: 0.897]
# Epoch [81], Loss[Train: 84596.197, Test: 115270.691], R2[Train: 0.923, Test: 0.890]
# Epoch [82], Loss[Train: 93686.201, Test: 130979.650], R2[Train: 0.915, Test: 0.875]
# Epoch [83], Loss[Train: 92202.280, Test: 139825.396], R2[Train: 0.916, Test: 0.866]
# Epoch [84], Loss[Train: 87203.483, Test: 105686.181], R2[Train: 0.921, Test: 0.899]
# Epoch [85], Loss[Train: 83776.779, Test: 106639.518], R2[Train: 0.924, Test: 0.898]
# Epoch [86], Loss[Train: 84674.939, Test: 107725.559], R2[Train: 0.923, Test: 0.897]
# Epoch [87], Loss[Train: 82115.414, Test: 103462.430], R2[Train: 0.925, Test: 0.901]
# Epoch [88], Loss[Train: 84030.963, Test: 106273.111], R2[Train: 0.923, Test: 0.898]
# Epoch [89], Loss[Train: 81767.432, Test: 103048.907], R2[Train: 0.925, Test: 0.901]
# Epoch [90], Loss[Train: 87974.406, Test: 110899.024], R2[Train: 0.920, Test: 0.894]
# Epoch [91], Loss[Train: 86884.828, Test: 107028.893], R2[Train: 0.921, Test: 0.897]
# Epoch [92], Loss[Train: 82289.095, Test: 110539.686], R2[Train: 0.925, Test: 0.894]
# Epoch [93], Loss[Train: 83240.996, Test: 108838.022], R2[Train: 0.924, Test: 0.896]
# Epoch [94], Loss[Train: 81280.001, Test: 108867.897], R2[Train: 0.926, Test: 0.896]
# Epoch [95], Loss[Train: 81351.587, Test: 102389.980], R2[Train: 0.926, Test: 0.902]
# Epoch [96], Loss[Train: 81244.796, Test: 102100.033], R2[Train: 0.926, Test: 0.902]
# Epoch [97], Loss[Train: 82239.066, Test: 101637.106], R2[Train: 0.925, Test: 0.903]
# Epoch [98], Loss[Train: 84504.944, Test: 101302.511], R2[Train: 0.923, Test: 0.903]
# Epoch [99], Loss[Train: 84362.951, Test: 101124.909], R2[Train: 0.923, Test: 0.903]
# Epoch [100], Loss[Train: 82554.861, Test: 103518.220], R2[Train: 0.925, Test: 0.901]
# Epoch [101], Loss[Train: 81665.044, Test: 104972.576], R2[Train: 0.926, Test: 0.899]
# Epoch [102], Loss[Train: 82663.587, Test: 104090.511], R2[Train: 0.925, Test: 0.900]
# Epoch [103], Loss[Train: 78471.235, Test: 108003.394], R2[Train: 0.928, Test: 0.897]
# Epoch [104], Loss[Train: 80093.892, Test: 107543.159], R2[Train: 0.927, Test: 0.897]
# Epoch [105], Loss[Train: 79533.276, Test: 105788.697], R2[Train: 0.928, Test: 0.899]
# Epoch [106], Loss[Train: 79791.578, Test: 101249.895], R2[Train: 0.927, Test: 0.903]
# Epoch [107], Loss[Train: 79611.352, Test: 106991.007], R2[Train: 0.927, Test: 0.897]
# Epoch [108], Loss[Train: 79176.269, Test: 103290.913], R2[Train: 0.928, Test: 0.901]
# Epoch [109], Loss[Train: 81609.491, Test: 100869.363], R2[Train: 0.926, Test: 0.903]
# Epoch [110], Loss[Train: 77074.933, Test: 102647.089], R2[Train: 0.930, Test: 0.902]
# Epoch [111], Loss[Train: 77034.469, Test: 101355.532], R2[Train: 0.930, Test: 0.903]
# Epoch [112], Loss[Train: 78119.373, Test: 100876.178], R2[Train: 0.929, Test: 0.903]
# Epoch [113], Loss[Train: 77936.419, Test: 100546.141], R2[Train: 0.929, Test: 0.904]
# Epoch [114], Loss[Train: 76893.788, Test: 100184.671], R2[Train: 0.930, Test: 0.904]
# Epoch [115], Loss[Train: 76605.100, Test: 103203.095], R2[Train: 0.930, Test: 0.901]
# Epoch [116], Loss[Train: 77537.813, Test: 100238.969], R2[Train: 0.929, Test: 0.904]
# Epoch [117], Loss[Train: 76662.570, Test: 102521.266], R2[Train: 0.930, Test: 0.902]
# Epoch [118], Loss[Train: 77471.023, Test: 103338.466], R2[Train: 0.929, Test: 0.901]
# Epoch [119], Loss[Train: 76978.808, Test: 103954.177], R2[Train: 0.930, Test: 0.900]
# Epoch [120], Loss[Train: 76823.511, Test: 102499.461], R2[Train: 0.930, Test: 0.902]
# Epoch [121], Loss[Train: 76866.637, Test: 99905.394], R2[Train: 0.930, Test: 0.904]
# Epoch [122], Loss[Train: 75771.154, Test: 101779.648], R2[Train: 0.931, Test: 0.902]
# Epoch [123], Loss[Train: 75817.332, Test: 100103.741], R2[Train: 0.931, Test: 0.904]
# Epoch [124], Loss[Train: 76047.709, Test: 101201.180], R2[Train: 0.931, Test: 0.903]
# Epoch [125], Loss[Train: 76589.989, Test: 99912.273], R2[Train: 0.930, Test: 0.904]
# Epoch [126], Loss[Train: 75809.605, Test: 99807.076], R2[Train: 0.931, Test: 0.904]
# Epoch [127], Loss[Train: 75934.872, Test: 100032.807], R2[Train: 0.931, Test: 0.904]
# Epoch [128], Loss[Train: 76114.803, Test: 100005.618], R2[Train: 0.931, Test: 0.904]
# Epoch [129], Loss[Train: 75703.795, Test: 100678.784], R2[Train: 0.931, Test: 0.904]
# Epoch [130], Loss[Train: 75722.000, Test: 100113.074], R2[Train: 0.931, Test: 0.904]
# Epoch [131], Loss[Train: 75799.084, Test: 99965.049], R2[Train: 0.931, Test: 0.904]
# Epoch [132], Loss[Train: 75560.383, Test: 100129.079], R2[Train: 0.931, Test: 0.904]
# Epoch [133], Loss[Train: 75783.572, Test: 99692.230], R2[Train: 0.931, Test: 0.904]
# Epoch [134], Loss[Train: 75651.783, Test: 99710.399], R2[Train: 0.931, Test: 0.904]
# Epoch [135], Loss[Train: 75630.549, Test: 100097.737], R2[Train: 0.931, Test: 0.904]
# Epoch [136], Loss[Train: 75992.660, Test: 99559.925], R2[Train: 0.931, Test: 0.905]
# Epoch [137], Loss[Train: 75334.509, Test: 101947.501], R2[Train: 0.931, Test: 0.902]
# Epoch [138], Loss[Train: 75497.320, Test: 99842.956], R2[Train: 0.931, Test: 0.904]
# Epoch [139], Loss[Train: 75968.838, Test: 99594.571], R2[Train: 0.931, Test: 0.905]
# Epoch [140], Loss[Train: 75721.061, Test: 99577.726], R2[Train: 0.931, Test: 0.905]
# Epoch [141], Loss[Train: 75522.347, Test: 100781.995], R2[Train: 0.931, Test: 0.903]
# Epoch [142], Loss[Train: 75573.076, Test: 100249.994], R2[Train: 0.931, Test: 0.904]
# Epoch [143], Loss[Train: 75773.235, Test: 100380.593], R2[Train: 0.931, Test: 0.904]
# Epoch [144], Loss[Train: 75392.568, Test: 100412.739], R2[Train: 0.931, Test: 0.904]
# Epoch [145], Loss[Train: 75428.974, Test: 99497.999], R2[Train: 0.931, Test: 0.905]
# Epoch [146], Loss[Train: 75172.005, Test: 100396.712], R2[Train: 0.931, Test: 0.904]
# Epoch [147], Loss[Train: 75600.555, Test: 100143.678], R2[Train: 0.931, Test: 0.904]
# Epoch [148], Loss[Train: 75498.542, Test: 99755.355], R2[Train: 0.931, Test: 0.904]
# Epoch [149], Loss[Train: 75372.869, Test: 99531.969], R2[Train: 0.931, Test: 0.905]
# Epoch [150], Loss[Train: 75339.326, Test: 100360.975], R2[Train: 0.931, Test: 0.904]
# Epoch [151], Loss[Train: 75160.974, Test: 99515.353], R2[Train: 0.931, Test: 0.905]
# Epoch [152], Loss[Train: 75374.630, Test: 99764.529], R2[Train: 0.931, Test: 0.904]
# Epoch [153], Loss[Train: 75249.239, Test: 99539.971], R2[Train: 0.931, Test: 0.905]
# Epoch [154], Loss[Train: 75246.540, Test: 99619.628], R2[Train: 0.931, Test: 0.905]
# Epoch [155], Loss[Train: 75384.240, Test: 99561.863], R2[Train: 0.931, Test: 0.905]
# Epoch [156], Loss[Train: 75249.569, Test: 101545.347], R2[Train: 0.931, Test: 0.903]
# Epoch [157], Loss[Train: 75475.737, Test: 99798.664], R2[Train: 0.931, Test: 0.904]
# Epoch [158], Loss[Train: 75356.253, Test: 99428.337], R2[Train: 0.931, Test: 0.905]
# Epoch [159], Loss[Train: 75170.241, Test: 99474.207], R2[Train: 0.931, Test: 0.905]
# Epoch [160], Loss[Train: 75190.020, Test: 99669.021], R2[Train: 0.931, Test: 0.905]
# Epoch [161], Loss[Train: 75178.067, Test: 99799.164], R2[Train: 0.931, Test: 0.904]
# Epoch [162], Loss[Train: 75216.152, Test: 99536.171], R2[Train: 0.931, Test: 0.905]
# Epoch [163], Loss[Train: 75207.838, Test: 99624.346], R2[Train: 0.931, Test: 0.905]
# Epoch [164], Loss[Train: 75123.423, Test: 99514.651], R2[Train: 0.932, Test: 0.905]
# Epoch [165], Loss[Train: 75091.320, Test: 99616.890], R2[Train: 0.932, Test: 0.905]
# Epoch [166], Loss[Train: 75139.030, Test: 99434.874], R2[Train: 0.932, Test: 0.905]
# Epoch [167], Loss[Train: 75125.784, Test: 99456.404], R2[Train: 0.932, Test: 0.905]
# Epoch [168], Loss[Train: 75057.873, Test: 99696.808], R2[Train: 0.932, Test: 0.904]
# Epoch [169], Loss[Train: 75106.245, Test: 99420.113], R2[Train: 0.932, Test: 0.905]
# Epoch [170], Loss[Train: 75127.981, Test: 99411.579], R2[Train: 0.932, Test: 0.905]
# Epoch [171], Loss[Train: 75076.458, Test: 99515.133], R2[Train: 0.932, Test: 0.905]
# Epoch [172], Loss[Train: 75089.816, Test: 99459.972], R2[Train: 0.932, Test: 0.905]
# Epoch [173], Loss[Train: 75167.095, Test: 99519.313], R2[Train: 0.931, Test: 0.905]
# Epoch [174], Loss[Train: 75162.093, Test: 99403.863], R2[Train: 0.931, Test: 0.905]
# Epoch [175], Loss[Train: 75059.089, Test: 99478.281], R2[Train: 0.932, Test: 0.905]
# Epoch [176], Loss[Train: 75068.898, Test: 99620.238], R2[Train: 0.932, Test: 0.905]
# Epoch [177], Loss[Train: 75054.108, Test: 99589.830], R2[Train: 0.932, Test: 0.905]
# Epoch [178], Loss[Train: 75087.852, Test: 99548.191], R2[Train: 0.932, Test: 0.905]
# Epoch [179], Loss[Train: 75065.553, Test: 99609.700], R2[Train: 0.932, Test: 0.905]
# Epoch [180], Loss[Train: 75069.974, Test: 99565.534], R2[Train: 0.932, Test: 0.905]
# Epoch [181], Loss[Train: 75058.455, Test: 99576.847], R2[Train: 0.932, Test: 0.905]
# Epoch [182], Loss[Train: 75042.722, Test: 99590.251], R2[Train: 0.932, Test: 0.905]
# Epoch [183], Loss[Train: 75057.518, Test: 99586.078], R2[Train: 0.932, Test: 0.905]
# Epoch [184], Loss[Train: 75047.357, Test: 99565.813], R2[Train: 0.932, Test: 0.905]
# Epoch [185], Loss[Train: 75053.623, Test: 99571.767], R2[Train: 0.932, Test: 0.905]
# Epoch [186], Loss[Train: 75046.834, Test: 99525.367], R2[Train: 0.932, Test: 0.905]
# Epoch [187], Loss[Train: 75040.549, Test: 99576.989], R2[Train: 0.932, Test: 0.905]
# Epoch [188], Loss[Train: 75052.992, Test: 99585.866], R2[Train: 0.932, Test: 0.905]
# Epoch [189], Loss[Train: 75043.928, Test: 99587.807], R2[Train: 0.932, Test: 0.905]
# Epoch [190], Loss[Train: 75036.979, Test: 99557.234], R2[Train: 0.932, Test: 0.905]
# Epoch [191], Loss[Train: 75030.457, Test: 99542.627], R2[Train: 0.932, Test: 0.905]
# Epoch [192], Loss[Train: 75033.483, Test: 99494.156], R2[Train: 0.932, Test: 0.905]
# Epoch [193], Loss[Train: 75027.434, Test: 99517.555], R2[Train: 0.932, Test: 0.905]
# Epoch [194], Loss[Train: 75027.370, Test: 99527.789], R2[Train: 0.932, Test: 0.905]
# Epoch [195], Loss[Train: 75031.011, Test: 99527.296], R2[Train: 0.932, Test: 0.905]
# Epoch [196], Loss[Train: 75024.795, Test: 99550.973], R2[Train: 0.932, Test: 0.905]
# Epoch [197], Loss[Train: 75034.212, Test: 99545.446], R2[Train: 0.932, Test: 0.905]
# Epoch [198], Loss[Train: 75027.507, Test: 99553.829], R2[Train: 0.932, Test: 0.905]
# Epoch [199], Loss[Train: 75027.630, Test: 99543.652], R2[Train: 0.932, Test: 0.905]
# Epoch [200], Loss[Train: 75026.269, Test: 99544.279], R2[Train: 0.932, Test: 0.905]
# Epoch [201], Loss[Train: 75026.880, Test: 99558.730], R2[Train: 0.932, Test: 0.905]
# Epoch [202], Loss[Train: 75024.674, Test: 99561.412], R2[Train: 0.932, Test: 0.905]
# Epoch [203], Loss[Train: 75027.856, Test: 99562.246], R2[Train: 0.932, Test: 0.905]
# Epoch [204], Loss[Train: 75026.356, Test: 99557.837], R2[Train: 0.932, Test: 0.905]
# Epoch [205], Loss[Train: 75026.923, Test: 99552.875], R2[Train: 0.932, Test: 0.905]
# Epoch [206], Loss[Train: 75024.649, Test: 99553.323], R2[Train: 0.932, Test: 0.905]
# Epoch [207], Loss[Train: 75024.945, Test: 99556.020], R2[Train: 0.932, Test: 0.905]
# Epoch [208], Loss[Train: 75024.857, Test: 99551.643], R2[Train: 0.932, Test: 0.905]
# Epoch [209], Loss[Train: 75024.139, Test: 99546.280], R2[Train: 0.932, Test: 0.905]
# Epoch [210], Loss[Train: 75023.205, Test: 99544.603], R2[Train: 0.932, Test: 0.905]
# Epoch [211], Loss[Train: 75022.631, Test: 99541.781], R2[Train: 0.932, Test: 0.905]
# Epoch [212], Loss[Train: 75022.639, Test: 99541.170], R2[Train: 0.932, Test: 0.905]
# Epoch [213], Loss[Train: 75026.011, Test: 99547.371], R2[Train: 0.932, Test: 0.905]
# Epoch [214], Loss[Train: 75022.964, Test: 99543.917], R2[Train: 0.932, Test: 0.905]
# Epoch [215], Loss[Train: 75022.902, Test: 99542.319], R2[Train: 0.932, Test: 0.905]
# Epoch [216], Loss[Train: 75022.746, Test: 99542.570], R2[Train: 0.932, Test: 0.905]
# Epoch [217], Loss[Train: 75022.686, Test: 99543.947], R2[Train: 0.932, Test: 0.905]
# Epoch [218], Loss[Train: 75023.426, Test: 99546.663], R2[Train: 0.932, Test: 0.905]
# Epoch [219], Loss[Train: 75023.184, Test: 99546.272], R2[Train: 0.932, Test: 0.905]
# Epoch [220], Loss[Train: 75023.031, Test: 99545.492], R2[Train: 0.932, Test: 0.905]
# Epoch [221], Loss[Train: 75023.033, Test: 99545.091], R2[Train: 0.932, Test: 0.905]
# Epoch [222], Loss[Train: 75023.101, Test: 99544.875], R2[Train: 0.932, Test: 0.905]
# Epoch [223], Loss[Train: 75022.595, Test: 99543.967], R2[Train: 0.932, Test: 0.905]
# Epoch [224], Loss[Train: 75022.860, Test: 99538.216], R2[Train: 0.932, Test: 0.905]
# Epoch [225], Loss[Train: 75022.509, Test: 99541.836], R2[Train: 0.932, Test: 0.905]
# Epoch [226], Loss[Train: 75022.211, Test: 99540.087], R2[Train: 0.932, Test: 0.905]
# Epoch [227], Loss[Train: 75022.111, Test: 99540.837], R2[Train: 0.932, Test: 0.905]
# Epoch [228], Loss[Train: 75023.097, Test: 99542.740], R2[Train: 0.932, Test: 0.905]
# Epoch [229], Loss[Train: 75022.719, Test: 99543.254], R2[Train: 0.932, Test: 0.905]
# Epoch [230], Loss[Train: 75022.821, Test: 99545.744], R2[Train: 0.932, Test: 0.905]
# Epoch [231], Loss[Train: 75024.538, Test: 99549.664], R2[Train: 0.932, Test: 0.905]
# Epoch [232], Loss[Train: 75023.509, Test: 99549.985], R2[Train: 0.932, Test: 0.905]
# Epoch [233], Loss[Train: 75023.733, Test: 99555.328], R2[Train: 0.932, Test: 0.905]
# Epoch [234], Loss[Train: 75025.349, Test: 99558.907], R2[Train: 0.932, Test: 0.905]
# Epoch [235], Loss[Train: 75025.430, Test: 99559.178], R2[Train: 0.932, Test: 0.905]
# Epoch [236], Loss[Train: 75025.024, Test: 99555.807], R2[Train: 0.932, Test: 0.905]
# Epoch [237], Loss[Train: 75024.295, Test: 99553.366], R2[Train: 0.932, Test: 0.905]
# Epoch [238], Loss[Train: 75024.356, Test: 99549.985], R2[Train: 0.932, Test: 0.905]
# Epoch [239], Loss[Train: 75023.680, Test: 99548.744], R2[Train: 0.932, Test: 0.905]
# Epoch [240], Loss[Train: 75023.185, Test: 99549.764], R2[Train: 0.932, Test: 0.905]
# Epoch [241], Loss[Train: 75023.824, Test: 99551.284], R2[Train: 0.932, Test: 0.905]
# Epoch [242], Loss[Train: 75024.009, Test: 99551.871], R2[Train: 0.932, Test: 0.905]
# Epoch [243], Loss[Train: 75023.524, Test: 99552.377], R2[Train: 0.932, Test: 0.905]
# Epoch [244], Loss[Train: 75024.426, Test: 99555.444], R2[Train: 0.932, Test: 0.905]
# Epoch [245], Loss[Train: 75025.119, Test: 99557.014], R2[Train: 0.932, Test: 0.905]
# Epoch [246], Loss[Train: 75024.217, Test: 99552.356], R2[Train: 0.932, Test: 0.905]
# Epoch [247], Loss[Train: 75024.205, Test: 99550.311], R2[Train: 0.932, Test: 0.905]
# Epoch [248], Loss[Train: 75025.889, Test: 99553.337], R2[Train: 0.932, Test: 0.905]
# Epoch [249], Loss[Train: 75024.424, Test: 99551.879], R2[Train: 0.932, Test: 0.905]
# Epoch [250], Loss[Train: 75024.367, Test: 99554.190], R2[Train: 0.932, Test: 0.905]
# Final Test Loss: 99554.1899

# %%
import matplotlib.pyplot as plt
import numpy as np

# 1) Epoch vs R^2
plt.figure(dpi=300, figsize=(5,5)) 

plt.rcParams['font.family'] = 'DeJavu Serif'
plt.rcParams['font.serif'] = ['Times New Roman']
plt.rcParams['font.size'] = 10

plt.plot(np.array(train_losses), label='Train')
plt.plot(np.array(test_losses), label='Validation')
plt.legend()
plt.xlabel('Epoch')
plt.ylabel(r'MSE Loss ($\mathcal{L})$')
plt.yscale("log") 
plt.xlim(-5,epoch_num)
plt.tight_layout()

# %% [markdown]
# # Save model

# %%
best_model_path = f'{args.save_model_dir}/epoch_{args.epoch_num}.pt'  
torch.save(best_state_dict, best_model_path)

# %% [markdown]
# # Evaluation

# %%
R2_K = evaluate_model(model, train_loader, device, args.cover_interval, overlap, args.save_model_dir)
# Out:
# Test R2 for E: 0.9316163063049316

# %%
R2_K = evaluate_model(model, test_loader, device, args.cover_interval, overlap, args.save_model_dir)
# Out:
# Test R2 for E: 0.9046220183372498

# %%
R2_K = evaluate_model(model, valid_loader, device, args.cover_interval, overlap, args.save_model_dir)
# Out:
# Test R2 for E: 0.9171638488769531
