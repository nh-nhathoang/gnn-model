# %%
import argparse
import numpy as np
import torch.nn as nn
import torch.optim as optim
import matplotlib.pyplot as plt

from torch_geometric.data import Data
from utils.GNN_data import *
from utils.GNN_architecture import GIN
from utils.train_model import train_model
from utils.evaluate_model import *

# %%
parser = argparse.ArgumentParser()
parser.add_argument('--batch_num', type=int, default=64, help='batch size') 
parser.add_argument('--epoch_num', type=int, default=200, help='Epoch number') 
parser.add_argument('--cover_interval', type=int, default=20, help='Cover interval')
parser.add_argument('--overlap', type=float, default=0.3, help='cover overlap')
parser.add_argument('--save_model_dir', type=str, default='./saved_model', help='saved GNN model directory')
args = parser.parse_args([])
#2 features
#epoch_num = 200 -> converge
#running time more than 30 mins
#drop out = 0.5

# %%
def load_inp_data(file_path, label):
    nodes, edges = [], []
    
    with open(file_path, 'r') as file:
        lines = file.readlines()

        node_section = False
        element_section = False

        for line in lines:
            line = line.strip()

            if "*Node" in line:
                node_section = True
                element_section = False
                continue

            if "*Element" in line:
                node_section = False
                element_section = True
                continue

            # Skip invalid lines like "*Nset" or "*Elset"
            if "*Nset" in line or "*Elset" in line:
                node_section = False
                element_section = False
                continue

            if node_section:
                parts = line.split(',')
                if len(parts) >= 3:
                    try:
                        x, y = float(parts[1].strip()), float(parts[2].strip())
                        nodes.append([x, y])
                    except ValueError:
                        continue

            if element_section:
                parts = line.split(',')
                if len(parts) >= 3 and parts[0].strip().isdigit() and parts[1].strip().isdigit() and parts[2].strip().isdigit():
                    start, end = int(parts[1].strip()) - 1, int(parts[2].strip()) - 1  # Convert 1-indexed to 0-indexed
                    
                    if start == end:
                        continue
                    
                    # Ensure indices are within valid range
                    if start < len(nodes) and end < len(nodes):
                        edges.append([start, end])
                    else:
                        print(f"Skipping invalid edge ({start+1}, {end+1}) in {file_path}")

    node_tensor = torch.tensor(nodes, dtype=torch.float)
    edge_tensor = torch.tensor(edges, dtype=torch.long).t().contiguous() if edges else torch.empty((2, 0), dtype=torch.long)

    data = Data(x=node_tensor, edge_index=edge_tensor, E=np.float64(label * 200.00))
    return data

# %% [markdown]
# # Data loading

# %%
import os
from glob import glob

folder_list = ['Kagome', 'Hexagonal', 'Demi-A', 'Demi-B', 'Demi-C']
base_path = '.'  

dataset = []

for folder in folder_list:
    results_path = os.path.join(base_path, folder, 'Results.txt')
    inp_folder = os.path.join(base_path, folder, 'inp_files')

    # Parse Results.txt in the current folder
    file_labels = {}
    with open(results_path, 'r') as file:
        for line in file:
            if line.strip() == "" or "E/Es" in line:
                continue
            try:
                file_name, label = line.strip().split(', ')
                filename = file_name.strip().split('.')[0]
                label = float(label)
                file_labels[filename] = label
            except ValueError:
                print(f"[{folder}] Skipping invalid line: {line.strip()}")

    # Load each corresponding .inp file
    for file, label in file_labels.items():
        file_path = os.path.join(inp_folder, f"{file}.inp")
        if os.path.exists(file_path):
            data = load_inp_data(file_path, label)
            if data is not None:
                dataset.append(data)
        else:
            print(f"[{folder}] Missing file: {file_path}")

# %%
dataset
# Out:
# [Data(x=[104, 2], edge_index=[2, 180], E=3.3342561035200005),
#  Data(x=[104, 2], edge_index=[2, 180], E=3.31936621094),
#  Data(x=[104, 2], edge_index=[2, 180], E=3.3175781250000003),
#  Data(x=[104, 2], edge_index=[2, 180], E=3.3117568359400003),
#  Data(x=[104, 2], edge_index=[2, 180], E=3.3090815429599996),
#  Data(x=[104, 2], edge_index=[2, 180], E=3.3022961425800004),
#  Data(x=[104, 2], edge_index=[2, 180], E=3.31983398438),
#  Data(x=[104, 2], edge_index=[2, 180], E=3.3201633300799998),
#  Data(x=[104, 2], edge_index=[2, 180], E=3.3031911621),
#  Data(x=[104, 2], edge_index=[2, 180], E=3.3095705566399998),
#  Data(x=[104, 2], edge_index=[2, 180], E=3.3185014648399997),
#  Data(x=[104, 2], edge_index=[2, 180], E=3.3280244140599997),
#  Data(x=[104, 2], edge_index=[2, 180], E=3.3147871093799997),
#  Data(x=[104, 2], edge_index=[2, 180], E=3.

#  Data(x=[104, 2], edge_index=[2, 180], E=0.395177398682),
#  Data(x=[104, 2], edge_index=[2, 180], E=0.517807434082),
#  Data(x=[104, 2], edge_index=[2, 180], E=0.472692504882),
#  Data(x=[104, 2], edge_index=[2, 180], E=0.420512237548),
#  Data(x=[104, 2], edge_index=[2, 180], E=0.5091539917),
#  Data(x=[104, 2], edge_index=[2, 180], E=0.746820922852),
#  Data(x=[104, 2], edge_index=[2, 180], E=0.760108886718),
#  Data(x=[104, 2], edge_index=[2, 180], E=0.555193359374),
#  Data(x=[104, 2], edge_index=[2, 180], E=0.342635681152),
#  Data(x=[104, 2], edge_index=[2, 180], E=0.635788757324),
#  Data(x=[104, 2], edge_index=[2, 180], E=0.5760905151360001),
#  Data(x=[104, 2], edge_index=[2, 180], E=0.408804992676),
#  Data(x=[104, 2], edge_index=[2, 180], E=0.334567504882),
#  Data(x=[104, 2], edge_index=[2, 180], E=0.977786254882),
#  Data(x=[104, 2], edge_index=[2, 180], E=0.15760511779779998),
#  Data(x=[104, 2], edge_index=[2, 180], E=0.47026889038),
#  Data(x=[104, 2], edge_index=[2, 180], E=0.373036834716),
#  Data(x=[104, 2], edge_index=[2, 180], E=0.6646353759760001),
#  Data(x=[104, 2], edge_index=[2, 180], E=0.851641540528),
#  Data(x=[104, 2], edge_index=[2, 180], E=0.510410827636),
#  Data(x=[104, 2], edge_index=[2, 180], E=0.655546936036),
#  Data(x=[104, 2], edge_index=[2, 180], E=0.600464355468),
#  Data(x=[104, 2], edge_index=[2, 180], E=0.571740478516),
#  Data(x=[104, 2], edge_index=[2, 180], E=0.533883728028),
#  Data(x=[104, 2], edge_index=[2, 180], E=0.9131180419920001),
#  Data(x=[104, 2], edge_index=[2, 180], E=0.25731515503),
#  Data(x=[104, 2], edge_index=[2, 180], E=0.5424776000980001),
#  Data(x=[104, 2], edge_index=[2, 180], E=0.31228118896400003),
#  Data(x=[104, 2], edge_index=[2, 180], E=0.325168029786),
#  Data(x=[104, 2], edge_index=[2, 180], E=0.493579711914),
#  Data(x=[104, 2], edge_index=[2, 180], E=0.440497406006),
#  Data(x=[104, 2], edge_index=[2, 180], E=0.291324249268),
#  Data(x=[104, 2], edge_index=[2, 180], E=0.393579467774),
#  Data(x=[104, 2], edge_index=[2, 180], E=0.790645751954),
#  Data(x=[104, 2], edge_index=[2, 180], E=0.33411227417),
#  Data(x=[104, 2], edge_index=[2, 180], E=0.665259094238),
#  Data(x=[104, 2], edge_index=[2, 180], E=0.20497180175799998),
#  Data(x=[104, 2], edge_index=[2, 180], E=0.483740112304),
#  Data(x=[104, 2], edge_index=[2, 180], E=0.68962097168),
#  Data(x=[104, 2], edge_index=[2, 180], E=0.218735656738),
#  Data(x=[104, 2], edge_index=[2, 180], E=0.1860778808594),
#  Data(x=[104, 2], edge_index=[2, 180], E=0.40209451294),
#  Data(x=[104, 2], edge_index=[2, 180], E=0.715299743652),
#  Data(x=[104, 2], edge_index=[2, 180], E=0.31457797241200003),
#  Data(x=[104, 2], edge_index=[2, 180], E=0.828740783692),
#  Data(x=[104, 2], edge_index=[2, 180], E=0.530280517578),
#  Data(x=[104, 2], edge_index=[2, 180], E=0.277645874024),
#  Data(x=[104, 2], edge_index=[2, 180], E=0.72646673584),
#  Data(x=[104, 2], edge_index=[2, 180], E=0.32877420044),
#  Data(x=[104, 2], edge_index=[2, 180], E=0.663323120118),
#  Data(x=[104, 2], edge_index=[2, 180], E=0.46111624145600005),
#  Data(x=[104, 2], edge_index=[2, 180], E=0.575880310058),
#  Data(x=[104, 2], edge_index=[2, 180], E=0.781407592774),
#  Data(x=[104, 2], edge_index=[2, 180], E=0.39139678954999996),
#  Data(x=[104, 2], edge_index=[2, 180], E=0.276095825196),
#  Data(x=[104, 2], edge_index=[2, 180], E=0.26860913086),
#  Data(x=[104, 2], edge_index=[2, 180], E=1.059904785156),
#  Data(x=[104, 2], edge_index=[2, 180], E=0.29747644043),
#  Data(x=[104, 2], edge_index=[2, 180], E=0.36215975952199997),
#  Data(x=[104, 2], edge_index=[2, 180], E=0.29481930542),
#  Data(x=[104, 2], edge_index=[2, 180], E=0.76285357666),
#  Data(x=[104, 2], edge_index=[2, 180], E=0.75840222168),
#  Data(x=[104, 2], edge_index=[2, 180], E=0.32587121582),
#  Data(x=[104, 2], edge_index=[2, 180], E=0.394257781982),
#  Data(x=[104, 2], edge_index=[2, 180], E=0.45642050170799997),
#  Data(x=[104, 2], edge_index=[2, 180], E=0.559645202636),
#  Data(x=[104, 2], edge_index=[2, 180], E=0.19170570373540002),
#  Data(x=[104, 2], edge_index=[2, 180], E=0.43446633911199994),
#  Data(x=[104, 2], edge_index=[2, 180], E=1.224805664062),
#  Data(x=[104, 2], edge_index=[2, 180], E=0.212350784302),
#  Data(x=[104, 2], edge_index=[2, 180], E=0.493954742432),
#  Data(x=[104, 2], edge_index=[2, 180], E=0.52021496582),
#  Data(x=[104, 2], edge_index=[2, 180], E=0.428672302246),
#  Data(x=[104, 2], edge_index=[2, 180], E=0.538377075196),
#  Data(x=[104, 2], edge_index=[2, 180], E=0.523897094726),
#  Data(x=[104, 2], edge_index=[2, 180], E=0.283607574462),
#  Data(x=[104, 2], edge_index=[2, 180], E=0.527367980958),
#  Data(x=[104, 2], edge_index=[2, 180], E=0.395174713134),
#  Data(x=[104, 2], edge_index=[2, 180], E=0.4203414917),
#  Data(x=[104, 2], edge_index=[2, 180], E=0.422726867676),
#  Data(x=[104, 2], edge_index=[2, 180], E=0.44756832885799996),
#  Data(x=[104, 2], edge_index=[2, 180], E=0.628430480958),
#  Data(x=[104, 2], edge_index=[2, 180], E=0.30038131713800004),
#  Data(x=[104, 2], edge_index=[2, 180], E=0.698901306152),
#  Data(x=[104, 2], edge_index=[2, 180], E=0.1996488494874),
#  Data(x=[104, 2], edge_index=[2, 180], E=0.746341796876),
#  Data(x=[104, 2], edge_index=[2, 180], E=0.5930285034180001),
#  Data(x=[104, 2], edge_index=[2, 180], E=0.254834457398),
#  Data(x=[104, 2], edge_index=[2, 180], E=0.294303192138),
#  Data(x=[104, 2], edge_index=[2, 180], E=0.41488262939400006),
#  Data(x=[104, 2], edge_index=[2, 180], E=0.8246994628900001),
#  ...]

# %%
batch_size = args.batch_num
epoch_num = args.epoch_num 
learning_rate = 0.001
overlap=args.overlap

# Check if the graph data is directed or undirected. For this study, undirected edges are used.
all_undirected_before = all(is_undirected(data) for data in dataset)
print(f'Graphs are undirected (before conversion): {all_undirected_before}')  # True if all are undirected, False otherwise

# Convert all graphs in the dataset to undirected
dataset = [make_undirected(data) for data in dataset]

# Re-check if all graphs are now undirected
all_undirected_after = all(is_undirected(data) for data in dataset)
print(f'Graphs are undirected (after conversion): {all_undirected_after}')  # True if all are undirected, False otherwise

dataset = normalize_planar_info(dataset)

# Split dataset for train/validation/test
train_loader, test_loader, valid_loader = prepare_dataset(dataset, batch_size, train_percentage=0.80, test_percentage=0.1)
# Out:
# Graphs are undirected (before conversion): False
# Graphs are undirected (after conversion): True
# Number of training graphs: 4004
# Number of test graphs: 500
# Number of vali graphs: 501

# %%
dataset[0]
# Out:
# Data(x=[104, 2], edge_index=[2, 360], E=3.3342561035200005)

# %%
E_vals = [data.E for data in dataset]

plt.figure(figsize=(5,5), dpi=300) 

plt.rcParams['font.serif'] = ['Times New Roman']
plt.rcParams['font.size'] = 13

labels = ['Kagome', 'Hexagonal', 'Demi-A', 'Demi-B', 'Demi-C']
markers = ['o', 's', '^', 'D', 'x']  # circle, square, triangle, diamond, cross
colors = ['blue', 'green', 'red', 'orange', 'purple']

size = 1001
for i in range(5):
    start = i * size
    end = (i + 1) * size
    x = range(start, end)
    y = E_vals[start:end]
    
    plt.plot(x, y, linestyle='none', marker=markers[i], color=colors[i],
             markersize=3, label=labels[i])

plt.ylabel(r'Elasticity $E$ (GPa)')
plt.xlabel('Samples')
plt.xlim([0,5*size+100])
plt.legend()
plt.tight_layout()

# %% [markdown]
# # GNN architecture

# %%
# Define the model, optimizer, and loss function

no_node_feature = dataset[0].x.shape[1]
model = GIN(dim_h=64, node_feature=no_node_feature)
optimizer = torch.optim.Adam(model.parameters(), lr=learning_rate, weight_decay=1e-4)
criterion = nn.MSELoss()
print(model)

# Define a learning rate scheduler
scheduler = optim.lr_scheduler.ReduceLROnPlateau(optimizer, mode='min', patience=5, factor=0.5, verbose=True)

# Use GPU if available, otherwise use CPU
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
model.to(device)

num_params = sum(p.numel() for p in model.parameters())
print("Number of parameters:", num_params)
# Out:
# GIN(
#   (conv1): GINConv(nn=Sequential(
#     (0): Linear(in_features=2, out_features=64, bias=True)
#     (1): BatchNorm1d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (2): ReLU()
#     (3): Linear(in_features=64, out_features=64, bias=True)
#     (4): ReLU()
#   ))
#   (conv2): GINConv(nn=Sequential(
#     (0): Linear(in_features=64, out_features=64, bias=True)
#     (1): BatchNorm1d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (2): ReLU()
#     (3): Linear(in_features=64, out_features=64, bias=True)
#     (4): ReLU()
#   ))
#   (conv3): GINConv(nn=Sequential(
#     (0): Linear(in_features=64, out_features=64, bias=True)
#     (1): BatchNorm1d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (2): ReLU()
#     (3): Linear(in_features=64, out_features=64, bias=True)
#     (4): ReLU()
#   ))
#   (lin1): Linear(in_features=192, out_features=128, bias=True)
#   (lin2): Linear(in_features=128, out_features=128, bias=True)
#   (lin4): Linear(in_features=128, out_features=1, bias=True)
#   (relu): ReLU()
# )
# Number of parameters: 62721
# /root/miniconda3/envs/GNN_ElasticModulus_Prediction/lib/python3.9/site-packages/torch/optim/lr_scheduler.py:62: UserWarning: The verbose parameter is deprecated. Please use get_last_lr() to access the learning rate.
#   warnings.warn(

# %% [markdown]
# ## Training

# %%
train_losses, test_losses, R2_trainings, R2_tests, best_state_dict = train_model(
    model, train_loader, test_loader, criterion, optimizer, scheduler, device=device, num_epochs=epoch_num)
# Out:
# Epoch [1], Loss[Train: 6.358, Test: 0.511], R2[Train: -4.809, Test: 0.525]
# Epoch [2], Loss[Train: 0.352, Test: 0.238], R2[Train: 0.678, Test: 0.779]
# Epoch [3], Loss[Train: 0.286, Test: 0.210], R2[Train: 0.739, Test: 0.805]
# Epoch [4], Loss[Train: 0.302, Test: 0.322], R2[Train: 0.724, Test: 0.700]
# Epoch [5], Loss[Train: 0.337, Test: 0.211], R2[Train: 0.692, Test: 0.804]
# Epoch [6], Loss[Train: 0.261, Test: 0.231], R2[Train: 0.762, Test: 0.786]
# Epoch [7], Loss[Train: 0.299, Test: 0.403], R2[Train: 0.727, Test: 0.626]
# Epoch [8], Loss[Train: 0.251, Test: 0.196], R2[Train: 0.771, Test: 0.818]
# Epoch [9], Loss[Train: 0.254, Test: 0.226], R2[Train: 0.768, Test: 0.790]
# Epoch [10], Loss[Train: 0.215, Test: 0.195], R2[Train: 0.803, Test: 0.819]
# Epoch [11], Loss[Train: 0.362, Test: 0.268], R2[Train: 0.669, Test: 0.751]
# Epoch [12], Loss[Train: 0.252, Test: 0.249], R2[Train: 0.770, Test: 0.768]
# Epoch [13], Loss[Train: 0.207, Test: 0.210], R2[Train: 0.811, Test: 0.805]
# Epoch [14], Loss[Train: 0.215, Test: 0.165], R2[Train: 0.804, Test: 0.847]
# Epoch [15], Loss[Train: 0.207, Test: 0.267], R2[Train: 0.811, Test: 0.752]
# Epoch [16], Loss[Train: 0.164, Test: 0.167], R2[Train: 0.850, Test: 0.845]
# Epoch [17], Loss[Train: 0.213, Test: 0.149], R2[Train: 0.805, Test: 0.861]
# Epoch [18], Loss[Train: 0.166, Test: 0.116], R2[Train: 0.849, Test: 0.892]
# Epoch [19], Loss[Train: 0.188, Test: 0.110], R2[Train: 0.828, Test: 0.898]
# Epoch [20], Loss[Train: 0.170, Test: 0.130], R2[Train: 0.844, Test: 0.879]
# Epoch [21], Loss[Train: 0.147, Test: 0.100], R2[Train: 0.866, Test: 0.907]
# Epoch [22], Loss[Train: 0.183, Test: 0.187], R2[Train: 0.833, Test: 0.826]
# Epoch [23], Loss[Train: 0.164, Test: 0.110], R2[Train: 0.850, Test: 0.898]
# Epoch [24], Loss[Train: 0.160, Test: 0.125], R2[Train: 0.854, Test: 0.884]
# Epoch [25], Loss[Train: 0.161, Test: 0.106], R2[Train: 0.853, Test: 0.901]
# Epoch [26], Loss[Train: 0.157, Test: 0.128], R2[Train: 0.857, Test: 0.881]
# Epoch [27], Loss[Train: 0.137, Test: 0.102], R2[Train: 0.875, Test: 0.905]
# Epoch [28], Loss[Train: 0.131, Test: 0.213], R2[Train: 0.881, Test: 0.802]
# Epoch [29], Loss[Train: 0.164, Test: 0.116], R2[Train: 0.850, Test: 0.892]
# Epoch [30], Loss[Train: 0.130, Test: 0.148], R2[Train: 0.881, Test: 0.863]
# Epoch [31], Loss[Train: 0.134, Test: 0.129], R2[Train: 0.877, Test: 0.880]
# Epoch [32], Loss[Train: 0.136, Test: 0.093], R2[Train: 0.876, Test: 0.913]
# Epoch [33], Loss[Train: 0.155, Test: 0.177], R2[Train: 0.858, Test: 0.835]
# Epoch [34], Loss[Train: 0.130, Test: 0.092], R2[Train: 0.881, Test: 0.914]
# Epoch [35], Loss[Train: 0.157, Test: 0.131], R2[Train: 0.857, Test: 0.878]
# Epoch [36], Loss[Train: 0.169, Test: 0.157], R2[Train: 0.846, Test: 0.854]
# Epoch [37], Loss[Train: 0.134, Test: 0.121], R2[Train: 0.877, Test: 0.888]
# Epoch [38], Loss[Train: 0.139, Test: 0.120], R2[Train: 0.873, Test: 0.888]
# Epoch [39], Loss[Train: 0.140, Test: 0.093], R2[Train: 0.872, Test: 0.914]
# Epoch [40], Loss[Train: 0.133, Test: 0.086], R2[Train: 0.878, Test: 0.920]
# Epoch [41], Loss[Train: 0.101, Test: 0.090], R2[Train: 0.907, Test: 0.916]
# Epoch [42], Loss[Train: 0.115, Test: 0.145], R2[Train: 0.895, Test: 0.865]
# Epoch [43], Loss[Train: 0.112, Test: 0.076], R2[Train: 0.897, Test: 0.929]
# Epoch [44], Loss[Train: 0.116, Test: 0.095], R2[Train: 0.894, Test: 0.912]
# Epoch [45], Loss[Train: 0.102, Test: 0.080], R2[Train: 0.907, Test: 0.926]
# Epoch [46], Loss[Train: 0.100, Test: 0.081], R2[Train: 0.909, Test: 0.925]
# Epoch [47], Loss[Train: 0.133, Test: 0.133], R2[Train: 0.878, Test: 0.877]
# Epoch [48], Loss[Train: 0.100, Test: 0.089], R2[Train: 0.909, Test: 0.917]
# Epoch [49], Loss[Train: 0.097, Test: 0.081], R2[Train: 0.911, Test: 0.925]
# Epoch [50], Loss[Train: 0.104, Test: 0.081], R2[Train: 0.905, Test: 0.925]
# Epoch [51], Loss[Train: 0.098, Test: 0.082], R2[Train: 0.910, Test: 0.924]
# Epoch [52], Loss[Train: 0.100, Test: 0.090], R2[Train: 0.909, Test: 0.916]
# Epoch [53], Loss[Train: 0.097, Test: 0.075], R2[Train: 0.911, Test: 0.930]
# Epoch [54], Loss[Train: 0.108, Test: 0.091], R2[Train: 0.901, Test: 0.916]
# Epoch [55], Loss[Train: 0.095, Test: 0.082], R2[Train: 0.913, Test: 0.924]
# Epoch [56], Loss[Train: 0.098, Test: 0.074], R2[Train: 0.911, Test: 0.931]
# Epoch [57], Loss[Train: 0.094, Test: 0.088], R2[Train: 0.914, Test: 0.918]
# Epoch [58], Loss[Train: 0.092, Test: 0.104], R2[Train: 0.916, Test: 0.903]
# Epoch [59], Loss[Train: 0.107, Test: 0.089], R2[Train: 0.903, Test: 0.918]
# Epoch [60], Loss[Train: 0.100, Test: 0.079], R2[Train: 0.909, Test: 0.927]
# Epoch [61], Loss[Train: 0.099, Test: 0.083], R2[Train: 0.910, Test: 0.923]
# Epoch [62], Loss[Train: 0.098, Test: 0.100], R2[Train: 0.910, Test: 0.907]
# Epoch [63], Loss[Train: 0.098, Test: 0.093], R2[Train: 0.910, Test: 0.914]
# Epoch [64], Loss[Train: 0.093, Test: 0.103], R2[Train: 0.915, Test: 0.905]
# Epoch [65], Loss[Train: 0.090, Test: 0.074], R2[Train: 0.918, Test: 0.931]
# Epoch [66], Loss[Train: 0.084, Test: 0.074], R2[Train: 0.924, Test: 0.931]
# Epoch [67], Loss[Train: 0.079, Test: 0.074], R2[Train: 0.928, Test: 0.931]
# Epoch [68], Loss[Train: 0.082, Test: 0.098], R2[Train: 0.925, Test: 0.909]
# Epoch [69], Loss[Train: 0.082, Test: 0.070], R2[Train: 0.925, Test: 0.935]
# Epoch [70], Loss[Train: 0.078, Test: 0.069], R2[Train: 0.929, Test: 0.936]
# Epoch [71], Loss[Train: 0.078, Test: 0.072], R2[Train: 0.929, Test: 0.933]
# Epoch [72], Loss[Train: 0.076, Test: 0.073], R2[Train: 0.931, Test: 0.932]
# Epoch [73], Loss[Train: 0.079, Test: 0.071], R2[Train: 0.928, Test: 0.934]
# Epoch [74], Loss[Train: 0.075, Test: 0.068], R2[Train: 0.932, Test: 0.937]
# Epoch [75], Loss[Train: 0.077, Test: 0.069], R2[Train: 0.930, Test: 0.936]
# Epoch [76], Loss[Train: 0.076, Test: 0.073], R2[Train: 0.931, Test: 0.933]
# Epoch [77], Loss[Train: 0.075, Test: 0.079], R2[Train: 0.932, Test: 0.927]
# Epoch [78], Loss[Train: 0.073, Test: 0.080], R2[Train: 0.933, Test: 0.926]
# Epoch [79], Loss[Train: 0.094, Test: 0.107], R2[Train: 0.914, Test: 0.901]
# Epoch [80], Loss[Train: 0.074, Test: 0.075], R2[Train: 0.933, Test: 0.930]
# Epoch [81], Loss[Train: 0.078, Test: 0.147], R2[Train: 0.929, Test: 0.863]
# Epoch [82], Loss[Train: 0.087, Test: 0.082], R2[Train: 0.920, Test: 0.924]
# Epoch [83], Loss[Train: 0.074, Test: 0.115], R2[Train: 0.933, Test: 0.893]
# Epoch [84], Loss[Train: 0.077, Test: 0.095], R2[Train: 0.929, Test: 0.912]
# Epoch [85], Loss[Train: 0.070, Test: 0.082], R2[Train: 0.936, Test: 0.924]
# Epoch [86], Loss[Train: 0.067, Test: 0.066], R2[Train: 0.939, Test: 0.939]
# Epoch [87], Loss[Train: 0.070, Test: 0.107], R2[Train: 0.936, Test: 0.900]
# Epoch [88], Loss[Train: 0.072, Test: 0.083], R2[Train: 0.934, Test: 0.923]
# Epoch [89], Loss[Train: 0.067, Test: 0.066], R2[Train: 0.938, Test: 0.938]
# Epoch [90], Loss[Train: 0.067, Test: 0.071], R2[Train: 0.939, Test: 0.934]
# Epoch [91], Loss[Train: 0.069, Test: 0.068], R2[Train: 0.937, Test: 0.937]
# Epoch [92], Loss[Train: 0.068, Test: 0.073], R2[Train: 0.938, Test: 0.933]
# Epoch [93], Loss[Train: 0.065, Test: 0.068], R2[Train: 0.940, Test: 0.937]
# Epoch [94], Loss[Train: 0.068, Test: 0.066], R2[Train: 0.938, Test: 0.939]
# Epoch [95], Loss[Train: 0.067, Test: 0.066], R2[Train: 0.939, Test: 0.939]
# Epoch [96], Loss[Train: 0.068, Test: 0.076], R2[Train: 0.938, Test: 0.929]
# Epoch [97], Loss[Train: 0.067, Test: 0.069], R2[Train: 0.939, Test: 0.936]
# Epoch [98], Loss[Train: 0.064, Test: 0.064], R2[Train: 0.941, Test: 0.940]
# Epoch [99], Loss[Train: 0.066, Test: 0.064], R2[Train: 0.939, Test: 0.941]
# Epoch [100], Loss[Train: 0.068, Test: 0.067], R2[Train: 0.938, Test: 0.937]
# Epoch [101], Loss[Train: 0.066, Test: 0.070], R2[Train: 0.940, Test: 0.935]
# Epoch [102], Loss[Train: 0.069, Test: 0.064], R2[Train: 0.937, Test: 0.941]
# Epoch [103], Loss[Train: 0.065, Test: 0.069], R2[Train: 0.940, Test: 0.936]
# Epoch [104], Loss[Train: 0.067, Test: 0.079], R2[Train: 0.939, Test: 0.927]
# Epoch [105], Loss[Train: 0.066, Test: 0.069], R2[Train: 0.940, Test: 0.936]
# Epoch [106], Loss[Train: 0.062, Test: 0.069], R2[Train: 0.943, Test: 0.936]
# Epoch [107], Loss[Train: 0.063, Test: 0.077], R2[Train: 0.943, Test: 0.928]
# Epoch [108], Loss[Train: 0.063, Test: 0.063], R2[Train: 0.942, Test: 0.942]
# Epoch [109], Loss[Train: 0.064, Test: 0.071], R2[Train: 0.942, Test: 0.934]
# Epoch [110], Loss[Train: 0.063, Test: 0.063], R2[Train: 0.942, Test: 0.942]
# Epoch [111], Loss[Train: 0.063, Test: 0.063], R2[Train: 0.942, Test: 0.941]
# Epoch [112], Loss[Train: 0.062, Test: 0.067], R2[Train: 0.944, Test: 0.938]
# Epoch [113], Loss[Train: 0.062, Test: 0.070], R2[Train: 0.943, Test: 0.935]
# Epoch [114], Loss[Train: 0.062, Test: 0.062], R2[Train: 0.943, Test: 0.942]
# Epoch [115], Loss[Train: 0.060, Test: 0.063], R2[Train: 0.945, Test: 0.941]
# Epoch [116], Loss[Train: 0.061, Test: 0.062], R2[Train: 0.944, Test: 0.942]
# Epoch [117], Loss[Train: 0.062, Test: 0.066], R2[Train: 0.944, Test: 0.938]
# Epoch [118], Loss[Train: 0.063, Test: 0.065], R2[Train: 0.943, Test: 0.939]
# Epoch [119], Loss[Train: 0.062, Test: 0.066], R2[Train: 0.943, Test: 0.939]
# Epoch [120], Loss[Train: 0.061, Test: 0.065], R2[Train: 0.945, Test: 0.940]
# Epoch [121], Loss[Train: 0.062, Test: 0.067], R2[Train: 0.944, Test: 0.938]
# Epoch [122], Loss[Train: 0.061, Test: 0.077], R2[Train: 0.945, Test: 0.928]
# Epoch [123], Loss[Train: 0.060, Test: 0.062], R2[Train: 0.945, Test: 0.942]
# Epoch [124], Loss[Train: 0.058, Test: 0.062], R2[Train: 0.947, Test: 0.943]
# Epoch [125], Loss[Train: 0.059, Test: 0.065], R2[Train: 0.946, Test: 0.940]
# Epoch [126], Loss[Train: 0.060, Test: 0.062], R2[Train: 0.945, Test: 0.942]
# Epoch [127], Loss[Train: 0.060, Test: 0.063], R2[Train: 0.946, Test: 0.942]
# Epoch [128], Loss[Train: 0.061, Test: 0.065], R2[Train: 0.944, Test: 0.940]
# Epoch [129], Loss[Train: 0.059, Test: 0.064], R2[Train: 0.946, Test: 0.941]
# Epoch [130], Loss[Train: 0.059, Test: 0.063], R2[Train: 0.946, Test: 0.942]
# Epoch [131], Loss[Train: 0.058, Test: 0.063], R2[Train: 0.947, Test: 0.942]
# Epoch [132], Loss[Train: 0.058, Test: 0.062], R2[Train: 0.947, Test: 0.942]
# Epoch [133], Loss[Train: 0.058, Test: 0.063], R2[Train: 0.947, Test: 0.942]
# Epoch [134], Loss[Train: 0.058, Test: 0.062], R2[Train: 0.947, Test: 0.942]
# Epoch [135], Loss[Train: 0.058, Test: 0.062], R2[Train: 0.947, Test: 0.943]
# Epoch [136], Loss[Train: 0.059, Test: 0.064], R2[Train: 0.946, Test: 0.941]
# Epoch [137], Loss[Train: 0.059, Test: 0.062], R2[Train: 0.946, Test: 0.942]
# Epoch [138], Loss[Train: 0.058, Test: 0.063], R2[Train: 0.947, Test: 0.941]
# Epoch [139], Loss[Train: 0.057, Test: 0.063], R2[Train: 0.948, Test: 0.942]
# Epoch [140], Loss[Train: 0.058, Test: 0.063], R2[Train: 0.947, Test: 0.942]
# Epoch [141], Loss[Train: 0.058, Test: 0.062], R2[Train: 0.947, Test: 0.942]
# Epoch [142], Loss[Train: 0.058, Test: 0.063], R2[Train: 0.947, Test: 0.942]
# Epoch [143], Loss[Train: 0.058, Test: 0.064], R2[Train: 0.947, Test: 0.941]
# Epoch [144], Loss[Train: 0.058, Test: 0.062], R2[Train: 0.947, Test: 0.942]
# Epoch [145], Loss[Train: 0.058, Test: 0.062], R2[Train: 0.947, Test: 0.943]
# Epoch [146], Loss[Train: 0.057, Test: 0.062], R2[Train: 0.948, Test: 0.943]
# Epoch [147], Loss[Train: 0.057, Test: 0.062], R2[Train: 0.948, Test: 0.942]
# Epoch [148], Loss[Train: 0.057, Test: 0.063], R2[Train: 0.948, Test: 0.942]
# Epoch [149], Loss[Train: 0.057, Test: 0.063], R2[Train: 0.948, Test: 0.942]
# Epoch [150], Loss[Train: 0.057, Test: 0.063], R2[Train: 0.948, Test: 0.942]
# Epoch [151], Loss[Train: 0.057, Test: 0.062], R2[Train: 0.948, Test: 0.942]
# Epoch [152], Loss[Train: 0.057, Test: 0.061], R2[Train: 0.948, Test: 0.943]
# Epoch [153], Loss[Train: 0.057, Test: 0.063], R2[Train: 0.948, Test: 0.941]
# Epoch [154], Loss[Train: 0.057, Test: 0.062], R2[Train: 0.948, Test: 0.943]
# Epoch [155], Loss[Train: 0.057, Test: 0.062], R2[Train: 0.948, Test: 0.943]
# Epoch [156], Loss[Train: 0.057, Test: 0.062], R2[Train: 0.948, Test: 0.942]
# Epoch [157], Loss[Train: 0.057, Test: 0.062], R2[Train: 0.948, Test: 0.942]
# Epoch [158], Loss[Train: 0.057, Test: 0.062], R2[Train: 0.948, Test: 0.942]
# Epoch [159], Loss[Train: 0.057, Test: 0.062], R2[Train: 0.948, Test: 0.943]
# Epoch [160], Loss[Train: 0.057, Test: 0.063], R2[Train: 0.948, Test: 0.942]
# Epoch [161], Loss[Train: 0.057, Test: 0.062], R2[Train: 0.948, Test: 0.942]
# Epoch [162], Loss[Train: 0.057, Test: 0.062], R2[Train: 0.948, Test: 0.943]
# Epoch [163], Loss[Train: 0.057, Test: 0.063], R2[Train: 0.948, Test: 0.942]
# Epoch [164], Loss[Train: 0.057, Test: 0.062], R2[Train: 0.948, Test: 0.942]
# Epoch [165], Loss[Train: 0.057, Test: 0.062], R2[Train: 0.948, Test: 0.942]
# Epoch [166], Loss[Train: 0.057, Test: 0.062], R2[Train: 0.948, Test: 0.943]
# Epoch [167], Loss[Train: 0.057, Test: 0.062], R2[Train: 0.948, Test: 0.943]
# Epoch [168], Loss[Train: 0.057, Test: 0.062], R2[Train: 0.948, Test: 0.943]
# Epoch [169], Loss[Train: 0.057, Test: 0.062], R2[Train: 0.948, Test: 0.943]
# Epoch [170], Loss[Train: 0.057, Test: 0.062], R2[Train: 0.948, Test: 0.942]
# Epoch [171], Loss[Train: 0.057, Test: 0.062], R2[Train: 0.948, Test: 0.942]
# Epoch [172], Loss[Train: 0.057, Test: 0.062], R2[Train: 0.948, Test: 0.943]
# Epoch [173], Loss[Train: 0.057, Test: 0.062], R2[Train: 0.948, Test: 0.942]
# Epoch [174], Loss[Train: 0.057, Test: 0.062], R2[Train: 0.948, Test: 0.943]
# Epoch [175], Loss[Train: 0.057, Test: 0.062], R2[Train: 0.948, Test: 0.942]
# Epoch [176], Loss[Train: 0.057, Test: 0.063], R2[Train: 0.948, Test: 0.942]
# Epoch [177], Loss[Train: 0.057, Test: 0.062], R2[Train: 0.948, Test: 0.942]
# Epoch [178], Loss[Train: 0.057, Test: 0.062], R2[Train: 0.948, Test: 0.942]
# Epoch [179], Loss[Train: 0.057, Test: 0.062], R2[Train: 0.948, Test: 0.943]
# Epoch [180], Loss[Train: 0.057, Test: 0.062], R2[Train: 0.948, Test: 0.943]
# Epoch [181], Loss[Train: 0.057, Test: 0.062], R2[Train: 0.948, Test: 0.942]
# Epoch [182], Loss[Train: 0.057, Test: 0.062], R2[Train: 0.948, Test: 0.942]
# Epoch [183], Loss[Train: 0.057, Test: 0.062], R2[Train: 0.948, Test: 0.943]
# Epoch [184], Loss[Train: 0.057, Test: 0.062], R2[Train: 0.948, Test: 0.943]
# Epoch [185], Loss[Train: 0.057, Test: 0.062], R2[Train: 0.948, Test: 0.943]
# Epoch [186], Loss[Train: 0.057, Test: 0.062], R2[Train: 0.948, Test: 0.943]
# Epoch [187], Loss[Train: 0.057, Test: 0.062], R2[Train: 0.948, Test: 0.942]
# Epoch [188], Loss[Train: 0.057, Test: 0.062], R2[Train: 0.948, Test: 0.943]
# Epoch [189], Loss[Train: 0.057, Test: 0.062], R2[Train: 0.948, Test: 0.943]
# Epoch [190], Loss[Train: 0.057, Test: 0.062], R2[Train: 0.948, Test: 0.942]
# Epoch [191], Loss[Train: 0.057, Test: 0.062], R2[Train: 0.948, Test: 0.942]
# Epoch [192], Loss[Train: 0.057, Test: 0.062], R2[Train: 0.948, Test: 0.943]
# Epoch [193], Loss[Train: 0.057, Test: 0.062], R2[Train: 0.948, Test: 0.943]
# Epoch [194], Loss[Train: 0.057, Test: 0.062], R2[Train: 0.948, Test: 0.942]
# Epoch [195], Loss[Train: 0.057, Test: 0.062], R2[Train: 0.948, Test: 0.942]
# Epoch [196], Loss[Train: 0.057, Test: 0.062], R2[Train: 0.948, Test: 0.942]
# Epoch [197], Loss[Train: 0.057, Test: 0.062], R2[Train: 0.948, Test: 0.943]
# Epoch [198], Loss[Train: 0.057, Test: 0.062], R2[Train: 0.948, Test: 0.942]
# Epoch [199], Loss[Train: 0.057, Test: 0.062], R2[Train: 0.948, Test: 0.942]
# Epoch [200], Loss[Train: 0.057, Test: 0.062], R2[Train: 0.948, Test: 0.942]
# Final Test Loss: 0.0621

# %%
plt.figure(figsize=(5,5), dpi=300) 

plt.rcParams['font.serif'] = ['Times New Roman']
plt.rcParams['font.size'] = 15

plt.plot(np.array(train_losses), label='Train')
plt.plot(np.array(test_losses), label='Validation')
plt.legend()
plt.xlabel('Epoch')
plt.ylabel('MSE Loss')
plt.yscale("log") 
plt.xlim(0,epoch_num)
plt.tight_layout()

# %% [markdown]
# # Save model

# %%
best_model_path = f'{args.save_model_dir}/epoch_{args.epoch_num}.pt'  
torch.save(best_state_dict, best_model_path)

# %% [markdown]
# ## Training and Validation data

# %%
R2 = evaluate_model(model, train_loader, device, args.cover_interval, overlap, args.save_model_dir)
# Out:
# Test R2 for E: 0.9481362700462341

# %%
R2 = evaluate_model(model, test_loader, device, args.cover_interval, overlap, args.save_model_dir)
# Out:
# Test R2 for E: 0.942293643951416

# %% [markdown]
# ## Testing data

# %%
R2 = evaluate_model(model, valid_loader, device, args.cover_interval, overlap, args.save_model_dir)
# Out:
# Test R2 for E: 0.9445675015449524
